# %% [markdown]
# #Import necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Importing Dataset

# %%
df=pd.read_csv("census.csv")
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
df.tail()
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
#               occupation   relationship   race     sex  capital.gain  \
# 32556    Protective-serv  Not-in-family  White    Male             0
# 32557       Tech-support           Wife  White  Female             0
# 32558  Machine-op-inspct        Husband  White    Male             0
# 32559       Adm-clerical      Unmarried  White  Female             0
# 32560       Adm-clerical      Own-child  White    Male             0
#
#        capital.loss  hours.per.week native.country income
# ...

# %% [markdown]
# #Exploratory Data Analysis(EDA)

# %%
df.shape   #checking the dimension of data
# Out:
# (32561, 15)

# %%
df.columns.tolist()
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education.num',
#  'marital.status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital.gain',
#  'capital.loss',
#  'hours.per.week',
#  'native.country',
#  'income']

# %%
df.dtypes   #datatype of all the columns
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.nunique()    #No. of unique values in each column
# Out:
# age                  73
# workclass             9
# fnlwgt            21648
# education            16
# education.num        16
# marital.status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital.gain        119
# capital.loss         92
# hours.per.week       94
# native.country       42
# income                2
# dtype: int64

# %%
#checking the value counts of unique values in each column...value_counts will give unique values and their number of presence at the same time

for i in df.columns:
    print(df[i].value_counts())
    print('\n')  #new line
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: age, Length: 73, dtype: int64
#
#
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
#
#
# 164190    13
# 203488    13
# 123011    13
# 113364    12
# 121124    12
#           ..
# 183522     1
# 44419      1
# 442612     1
# 374833     1
# 257302     1
# Name: fnlwgt, Length: 21648, dtype: int64
#
#
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# ...

# %%
df.isnull().sum()   #sum of all the null values in each columns
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
#No null values in any column

# %%
#But we can see some ? in workclass column,occupation column and native country column will replace those will null values

# %%
#checking the ? in workclass column
df.loc[df['workclass']=="?"]   #loc checks by the column name and iloc checks by the index number of the column
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 14      51         ?  172175     Doctorate             16       Never-married
# 24      61         ?  135285       HS-grad              9  Married-civ-spouse
# 44      71         ?  100820       HS-grad              9  Married-civ-spouse
# ...    ...       ...     ...           ...            ...                 ...
# 32533   35         ?  320084     Bachelors             13  Married-civ-spouse
# 32534   30         ?   33811     Bachelors             13       Never-married
# 32541   71         ?  287372     Doctorate             16  Married-civ-spouse
# 32543   41         ?  202822       HS-grad              9           Separated
# 32544   72         ?  129912       HS-grad              9  Married-civ-spouse
#
# ...

# %%
#checking the ? in occupation column
df.loc[df['occupation']=="?"]   #loc checks by the column name and iloc checks by the index number of the column
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 14      51         ?  172175     Doctorate             16       Never-married
# 24      61         ?  135285       HS-grad              9  Married-civ-spouse
# 44      71         ?  100820       HS-grad              9  Married-civ-spouse
# ...    ...       ...     ...           ...            ...                 ...
# 32533   35         ?  320084     Bachelors             13  Married-civ-spouse
# 32534   30         ?   33811     Bachelors             13       Never-married
# 32541   71         ?  287372     Doctorate             16  Married-civ-spouse
# 32543   41         ?  202822       HS-grad              9           Separated
# 32544   72         ?  129912       HS-grad              9  Married-civ-spouse
#
# ...

# %%
#checking the ? in native country column
df.loc[df['native.country']=="?"]   #loc checks by the column name and iloc checks by the index number of the column
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 9       41           Private   70037  Some-college             10
# 18      22           Private  119592    Assoc-acdm             12
# 65      60      Self-emp-inc  226355     Assoc-voc             11
# 86      39  Self-emp-not-inc  218490   Prof-school             15
# 87      43       Federal-gov  156996   Prof-school             15
# ...    ...               ...     ...           ...            ...
# 32459   44      Self-emp-inc   71556       Masters             14
# 32476   58      Self-emp-inc  181974     Doctorate             16
# 32498   42  Self-emp-not-inc  217597       HS-grad              9
# 32515   39           Private  107302       HS-grad              9
# 32528   81                 ?  120478     Assoc-voc             11
#
#            marital.status         occupation   relationship  \
# 9           Never-married       Craft-repair      Unmarried
# ...

# %%
#Now replacing that with null values
df["workclass"]=df["workclass"].replace("?", np.nan)
df["occupation"]=df["occupation"].replace("?", np.nan)
df["native.country"]=df["native.country"].replace("?", np.nan)

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90       NaN   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66       NaN  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                NaN  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                NaN      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
#All the ? values are replaced by null values

# %%
df.isnull().sum()   #now we can see that there are nan values present in columns now
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %% [markdown]
# #Now that we have changed the ? to null values we can handle the null values. Now replacing the NaN values by mode of the column

# %%
#filling null values with mode value

df['workclass']=df['workclass'].fillna(df['workclass'].mode()[0])
df['occupation']=df['occupation'].fillna(df['occupation'].mode()[0])
df['native.country']=df['native.country'].fillna(df['native.country'].mode()[0])

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
#No more null values

# %%
sns.heatmap(df.isnull())   #single colour heatmap as no null values are present
# Out:
# <AxesSubplot:>

# %% [markdown]
# #Data Preprocessing

# %%
#Removing all the unnecessary columns in the datset

# %%
#The "final weight" column is related to the weighting methodology and may not provide meaningful information for predicting income. It can be dropped.

df.drop("fnlwgt",axis=1,inplace=True)

# %%
#This column represents the numerical representation of education level, which is already present in education column

df.drop("education.num",axis=1,inplace=True)

# %%
#Native country of the individuals are not needed for predicting their income
df.drop("native.country",axis=1,inplace=True)

# %%
df
# Out:
#        age workclass     education      marital.status         occupation  \
# 0       90   Private       HS-grad             Widowed     Prof-specialty
# 1       82   Private       HS-grad             Widowed    Exec-managerial
# 2       66   Private  Some-college             Widowed     Prof-specialty
# 3       54   Private       7th-8th            Divorced  Machine-op-inspct
# 4       41   Private  Some-college           Separated     Prof-specialty
# ...    ...       ...           ...                 ...                ...
# 32556   22   Private  Some-college       Never-married    Protective-serv
# 32557   27   Private    Assoc-acdm  Married-civ-spouse       Tech-support
# 32558   40   Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 32559   58   Private       HS-grad             Widowed       Adm-clerical
# 32560   22   Private       HS-grad       Never-married       Adm-clerical
#
#         relationship   race     sex  capital.gain  capital.loss  \
# ...

# %%
#Seperating Numerical and categorical columns

categorical_col=[]
for i in df.columns:
    if df.dtypes[i]=='object':
        categorical_col.append(i)
print("Categorical columns are:", categorical_col)
print('\n')

numerical_col=[]
for i in df.columns:
    if df.dtypes[i]!='object':
        numerical_col.append(i)
print("Numerical columns are:", numerical_col)
print("\n")
# Out:
# Categorical columns are: ['workclass', 'education', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'income']
#
#
# Numerical columns are: ['age', 'capital.gain', 'capital.loss', 'hours.per.week']

# %%
df.nunique().to_frame("Number of unique values")
# Out:
#                 Number of unique values
# age                                  73
# workclass                             8
# education                            16
# marital.status                        7
# occupation                           14
# relationship                          6
# race                                  5
# sex                                   2
# capital.gain                        119
# capital.loss                         92
# hours.per.week                       94
# income                                2

# %%
#statistical summary of numerical values

df.describe()
# Out:
#                 age  capital.gain  capital.loss  hours.per.week
# count  32561.000000  32561.000000  32561.000000    32561.000000
# mean      38.581647   1077.648844     87.303830       40.437456
# std       13.640433   7385.292085    402.960219       12.347429
# min       17.000000      0.000000      0.000000        1.000000
# 25%       28.000000      0.000000      0.000000       40.000000
# 50%       37.000000      0.000000      0.000000       40.000000
# 75%       48.000000      0.000000      0.000000       45.000000
# max       90.000000  99999.000000   4356.000000       99.000000

# %%
#if mean>median its right skewed i.e. in capital gain and capital loss
#max value is very high than the 75% data i.e. outliers are present

# %% [markdown]
# #Data Visualization

# %% [markdown]
# #### Univariate analysis

# %%
income_datamap=sns.countplot(df["income"],data=df)
print(df["income"].value_counts())
# Out:
# <=50K    24720
# >50K      7841
# Name: income, dtype: int64

# %%
#There are 76% people that are earning more than 50k

# %%
datamap=sns.countplot(df["sex"],data=df)
print(df["sex"].value_counts())
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %%
#No. of males are higher than the no. of females

# %%
datamap=sns.countplot(df["race"],data=df)
print(df["race"].value_counts())
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
#Here we can see that White people are maximum in number than any other race

# %%
datamap=sns.countplot(df["relationship"],data=df)
print(df["relationship"].value_counts())
# Out:
# Husband           13193
# Not-in-family      8305
# Own-child          5068
# Unmarried          3446
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
#The highest count in relationship is of husbands

# %%
datamap=sns.countplot(df["marital.status"],data=df)
print(df["marital.status"].value_counts())
# Out:
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital.status, dtype: int64

# %%
datamap=sns.countplot(df["workclass"],data=df)
print(df["workclass"].value_counts())
# Out:
# Private             24532
# Self-emp-not-inc     2541
# Local-gov            2093
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
plt.figure(figsize=(10,6), facecolor='white')
plotnumber=1
for col in numerical_col:
    if plotnumber<=4:
        ax=plt.subplot(2,2,plotnumber)   
        sns.distplot(df[col],color='m')
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# #### Bivariate Analysis

# %%
sns.stripplot(y="age",x="income",data=df)
plt.show()

# %%
#Comparing age and income of people here

# %%
sns.stripplot(y="capital.gain",x="income",data=df)
plt.show()

# %%
sns.stripplot(y="capital.loss",x="income",data=df)
plt.show()

# %%
sns.catplot(x='income',col='sex',data=df,kind='count',palette='spring_r')

# %%
#This shows us the number of males and females that have the income greater or lesser than 50k

# %%
sns.catplot(x='workclass',col='income',data=df,kind='count',palette='spring_r')

# %%
sns.catplot(x='race',col='income',data=df,kind='count',palette='spring_r')

# %%
#Here we can see the count of income distribution according to different race of people

# %%
sns.catplot(x='relationship',col='income',data=df,kind='count',palette='spring_r')
plt.tight_layout()

# %%
sns.catplot(x='marital.status',col='income',data=df,kind='count',palette='spring_r')
plt.tight_layout()

# %% [markdown]
# #### Multivariate Analysis

# %%
sns.pairplot(df,hue="income",palette="Dark2")
plt.show()

# %% [markdown]
# #### Checking for outliers

# %%
#By plotting boxplot

plt.figure(figsize=(10,6),facecolor='white')
plotnumber=1
for col in numerical_col:
    if plotnumber<=4:
        ax=plt.subplot(2,2,plotnumber)
        sns.boxplot(df[col],palette='bright')
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation=0,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
#Here we can see that all the 4 numerical variables have outliers present in them

# %%
#Removing outliers by z-score

from scipy.stats import zscore
out_features=df[['age','capital.gain','capital.loss','hours.per.week']]
z=np.abs(zscore(out_features))  
z
# Out:
#             age  capital.gain  capital.loss  hours.per.week
# 0      3.769612       0.14592     10.593507        0.035429
# 1      3.183112       0.14592     10.593507        1.817204
# 2      2.010110       0.14592     10.593507        0.035429
# 3      1.130359       0.14592      9.461864        0.035429
# 4      0.177296       0.14592      9.461864        0.035429
# ...         ...           ...           ...             ...
# 32556  1.215643       0.14592      0.216660        0.035429
# 32557  0.849080       0.14592      0.216660        0.197409
# 32558  0.103983       0.14592      0.216660        0.035429
# 32559  1.423610       0.14592      0.216660        0.035429
# 32560  1.215643       0.14592      0.216660        1.655225
#
# [32561 rows x 4 columns]

# %%
#threshold=3

np.where(z>3)
# Out:
# (array([    0,     0,     1, ..., 32528, 32528, 32534], dtype=int64),
#  array([0, 2, 0, ..., 0, 3, 3], dtype=int64))

# %%
#Now removing the data above Z score and creating a new df

df1=df[(z<3).all(axis=1)]  
df1
# Out:
#        age  workclass     education      marital.status         occupation  \
# 1470    62  Local-gov     Bachelors  Married-civ-spouse       Adm-clerical
# 1471    72  Local-gov     Doctorate  Married-civ-spouse    Exec-managerial
# 1472    76    Private   Prof-school  Married-civ-spouse     Prof-specialty
# 1473    66    Private  Some-college  Married-civ-spouse   Transport-moving
# 1474    33  Local-gov       HS-grad            Divorced       Adm-clerical
# ...    ...        ...           ...                 ...                ...
# 32556   22    Private  Some-college       Never-married    Protective-serv
# 32557   27    Private    Assoc-acdm  Married-civ-spouse       Tech-support
# 32558   40    Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 32559   58    Private       HS-grad             Widowed       Adm-clerical
# 32560   22    Private       HS-grad       Never-married       Adm-clerical
#
#         relationship   race     sex  capital.gain  capital.loss  \
# ...

# %%
print("Old dataframe",df.shape[0])  #df.shape[0] will give only the rows
print("New dataframe",df1.shape[0])
# Out:
# Old dataframe 32561
# New dataframe 30357

# %%
#Checking the data loss percentage after removing the outliers

print("Data Loss Percentage:", ((df.shape[0]-df1.shape[0])/df.shape[0])*100)    #Change in data/original data *100
# Out:
# Data Loss Percentage: 6.76883388102331

# %%
#Now lets check with IQR method:

#1st Quantile
Q1=out_features.quantile(0.25)

#3rd Quantile
Q3=out_features.quantile(0.75)

IQR=Q3-Q1

df2=df[~((df < (Q1-1.5*IQR))|(df> (Q3+ 1.5*IQR))).any(axis=1)]

# %%
df2
# Out:
#        age         workclass     education      marital.status  \
# 4232    38           Private       HS-grad            Divorced
# 4233    53           Private          11th  Married-civ-spouse
# 4234    28           Private     Bachelors  Married-civ-spouse
# 4235    37           Private       Masters  Married-civ-spouse
# 4237    52  Self-emp-not-inc       HS-grad  Married-civ-spouse
# ...    ...               ...           ...                 ...
# 32555   53           Private       Masters  Married-civ-spouse
# 32556   22           Private  Some-college       Never-married
# 32557   27           Private    Assoc-acdm  Married-civ-spouse
# 32558   40           Private       HS-grad  Married-civ-spouse
# 32559   58           Private       HS-grad             Widowed
#
#               occupation   relationship   race     sex  capital.gain  \
# 4232   Handlers-cleaners  Not-in-family  White    Male             0
# ...

# %%
print("Old dataframe",df.shape[0])  #df.shape[0] will give only the rows
print("New dataframe",df2.shape[0])
# Out:
# Old dataframe 32561
# New dataframe 20395

# %%
#Checking the data loss percentage after removing the outliers

print("Data Loss Percentage:", ((df.shape[0]-df2.shape[0])/df.shape[0])*100)    #Change in data/original data *100
# Out:
# Data Loss Percentage: 37.363717330548816

# %% [markdown]
# #This means both methods of removing outliers are acceptable. We can go ahead with any one of these. We will choose z score method as its giving less data loss comparatively.

# %%
df=df1

# %% [markdown]
# #### Checking for Skewness

# %%
#only on numerical columns

df.skew()
# Out:
# age                0.492040
# capital.gain       4.955362
# capital.loss      29.924463
# hours.per.week    -0.351586
# dtype: float64

# %%
#We can see highly skewed data in capital.gain and capital.loss

# %% [markdown]
# #### Removing Skewness

# %%
import scipy.stats as stats

# %%
#Removing skewness by using cuberoot

df['capital.gain']=np.cbrt(df['capital.gain'])
df['capital.loss']=np.cbrt(df['capital.loss'])

# %%
#Again checking skewness

df.skew()
# Out:
# age                0.492040
# capital.gain       3.383159
# capital.loss      25.994703
# hours.per.week    -0.351586
# dtype: float64

# %%
#The data in capital gain and loss columns are still skewed. We will not remove the columns though else it will be 50% of data loss

# %% [markdown]
# #### Encoding Categorical columns

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))
        
df
# Out:
#        age  workclass  education  marital.status  occupation  relationship  \
# 1470    62        1.0        9.0             2.0         0.0           5.0
# 1471    72        1.0       10.0             2.0         3.0           0.0
# 1472    76        3.0       14.0             2.0         9.0           0.0
# 1473    66        3.0       15.0             2.0        13.0           0.0
# 1474    33        1.0       11.0             0.0         0.0           3.0
# ...    ...        ...        ...             ...         ...           ...
# 32556   22        3.0       15.0             4.0        10.0           1.0
# 32557   27        3.0        7.0             2.0        12.0           5.0
# 32558   40        3.0       11.0             2.0         6.0           0.0
# 32559   58        3.0       11.0             6.0         0.0           4.0
# 32560   22        3.0       11.0             4.0         0.0           3.0
#
#        race  sex  capital.gain  capital.loss  hours.per.week  income
# ...

# %%
df.info()   #no object data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30357 entries, 1470 to 32560
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30357 non-null  int64
#  1   workclass       30357 non-null  float64
#  2   education       30357 non-null  float64
#  3   marital.status  30357 non-null  float64
#  4   occupation      30357 non-null  float64
#  5   relationship    30357 non-null  float64
#  6   race            30357 non-null  float64
#  7   sex             30357 non-null  float64
#  8   capital.gain    30357 non-null  float64
#  9   capital.loss    30357 non-null  float64
#  10  hours.per.week  30357 non-null  int64
#  11  income          30357 non-null  float64
# dtypes: float64(10), int64(2)
# memory usage: 3.0 MB

# %%
df.describe()  #count of all the values is same i.e. there are no null values
# Out:
#                 age     workclass     education  marital.status    occupation  \
# count  30357.000000  30357.000000  30357.000000    30357.000000  30357.000000
# mean      38.153935      3.084824     10.279771        2.625095      6.108706
# std       13.365285      1.101165      3.899274        1.514547      3.980662
# min       17.000000      0.000000      0.000000        0.000000      0.000000
# 25%       27.000000      3.000000      9.000000        2.000000      3.000000
# 50%       37.000000      3.000000     11.000000        2.000000      6.000000
# 75%       47.000000      3.000000     12.000000        4.000000      9.000000
# max       79.000000      7.000000     15.000000        6.000000     13.000000
#
#        relationship          race           sex  capital.gain  capital.loss  \
# count  30357.000000  30357.000000  30357.000000  30357.000000  30357.000000
# mean       1.479000      3.661264      0.661528      1.467191      0.014018
# ...

# %% [markdown]
# #### Correlation between target variable and independent variables

# %%
cor=df.corr()    #-1 represents highly negative correlation and +1 is highly positive correlation
cor
# Out:
#                      age  workclass  education  marital.status  occupation  \
# age             1.000000   0.032251  -0.011900       -0.283931   -0.001921
# workclass       0.032251   1.000000   0.002720       -0.015715    0.008816
# education      -0.011900   0.002720   1.000000       -0.036179   -0.042653
# marital.status -0.283931  -0.015715  -0.036179        1.000000    0.035091
# occupation     -0.001921   0.008816  -0.042653        0.035091    1.000000
# relationship   -0.266217  -0.057612  -0.008801        0.184906   -0.036220
# race            0.025281   0.046455   0.015513       -0.066523   -0.004068
# sex             0.085818   0.068694  -0.031554       -0.123746    0.048950
# capital.gain    0.128865   0.006161   0.023465       -0.070455    0.007328
# capital.loss    0.020278  -0.010005  -0.000736       -0.015947   -0.000892
# hours.per.week  0.089523   0.027099   0.056772       -0.194706   -0.023300
# ...

# %%
#We can visualize this by plotting a heatmap

plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),linewidths=0.1,fmt=".1g",linecolor="black",annot=True,cmap="Blues_r")  
plt.yticks(rotation=0)
plt.show()

# %%
#We can see high correlation betwrrn relationship and sex column

# %%
df.corr()["income"].sort_values(ascending=False)   #arrange the correlation in descending order
# Out:
# income            1.000000
# capital.gain      0.312451
# age               0.236777
# hours.per.week    0.231158
# sex               0.209064
# education         0.074645
# race              0.072191
# occupation        0.030601
# workclass        -0.006844
# capital.loss     -0.017106
# marital.status   -0.194824
# relationship     -0.245474
# Name: income, dtype: float64

# %% [markdown]
# #No feature variable is having highly positive correlation with the target columns i.e. they are not predicting too much in its prediction.

# %% [markdown]
# #### Visualizing the correlation between the label and other features using bar plot

# %%
plt.figure(figsize=(22,7))
df.corr()["income"].sort_values(ascending=False).drop(["income"]).plot(kind='bar',color='m')  
plt.xlabel('Feature',fontsize=15)
plt.ylabel('Target',fontsize=15)
plt.title("Correlation between Target and features using bar plot")
plt.show()

# %% [markdown]
# #### Seperating Features(independent variables) and Label(Dependent or Target variable)

# %%
x=df.drop(["income"],axis=1)
y=df["income"]

# %%
x
# Out:
#        age  workclass  education  marital.status  occupation  relationship  \
# 1470    62        1.0        9.0             2.0         0.0           5.0
# 1471    72        1.0       10.0             2.0         3.0           0.0
# 1472    76        3.0       14.0             2.0         9.0           0.0
# 1473    66        3.0       15.0             2.0        13.0           0.0
# 1474    33        1.0       11.0             0.0         0.0           3.0
# ...    ...        ...        ...             ...         ...           ...
# 32556   22        3.0       15.0             4.0        10.0           1.0
# 32557   27        3.0        7.0             2.0        12.0           5.0
# 32558   40        3.0       11.0             2.0         6.0           0.0
# 32559   58        3.0       11.0             6.0         0.0           4.0
# 32560   22        3.0       11.0             4.0         0.0           3.0
#
#        race  sex  capital.gain  capital.loss  hours.per.week
# ...

# %% [markdown]
# #### Feature scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)  
x
# Out:
#             age  workclass  education  marital.status  occupation  \
# 0      1.784209  -1.893321  -0.328213       -0.412734   -1.534621
# 1      2.532428  -1.893321  -0.071751       -0.412734   -0.780965
# 2      2.831716  -0.077032   0.954098       -0.412734    0.726347
# 3      2.083496  -0.077032   1.210560       -0.412734    1.731221
# 4     -0.385627  -1.893321   0.184712       -1.733282   -1.534621
# ...         ...        ...        ...             ...         ...
# 30352 -1.208669  -0.077032   1.210560        0.907815    0.977565
# 30353 -0.834559  -0.077032  -0.841137       -0.412734    1.480003
# 30354  0.138126  -0.077032   0.184712       -0.412734   -0.027309
# 30355  1.484921  -0.077032   0.184712        2.228363   -1.534621
# 30356 -1.208669  -0.077032   0.184712        0.907815   -1.534621
#
#        relationship      race       sex  capital.gain  capital.loss  \
# 0          2.188494  0.397221 -1.398017     -0.287547     30.197020
# ...

# %% [markdown]
# #### Checking Variance Inflation Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#     VIF values        Features
# 0     1.171907             age
# 1     1.007427       workclass
# 2     1.009621       education
# 3     1.136600  marital.status
# 4     1.007011      occupation
# 5     1.661695    relationship
# 6     1.018950            race
# 7     1.541296             sex
# 8     1.026876    capital.gain
# 9     1.002724    capital.loss
# 10    1.117722  hours.per.week

# %%
#All the columns have vif under control. No problem of multicolliniarity

# %%
y.value_counts()
# Out:
# 0.0    23625
# 1.0     6732
# Name: income, dtype: int64

# %% [markdown]
# #Here we can see that data is not balance since there is classification problem and the model can give priority to higher data resulting in biased analysis. Now we will balance the target variable data using oversampling method

# %%
# !pip install imblearn

# %%
#Oversampling

from imblearn.over_sampling import SMOTE
SM=SMOTE()
x,y=SM.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 0.0    23625
# 1.0    23625
# Name: income, dtype: int64

# %%
#Now the data is balanced by the ratio of 1:1 ...now we can build machine learning Classification model

# %% [markdown]
# #### Modelling

# %%
#Importing necessary libraries



from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    RFR=RandomForestClassifier()
    RFR.fit(x_train,y_train)
    pred=RFR.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is",maxAccu,"at random_state",maxRS)
# Out:
# Best accuracy is 0.8972839506172839 at random_state 31

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %% [markdown]
# #### Classification Algorithms

# %%
#Importing all the classification libraries

from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score

# %%
#Checking accuracy for Random Forest Classifier

RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC=RFC.predict(x_test)
print(accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.8956613756613757
# [[6291  757]
#  [ 722 6405]]
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.89      0.89      7048
#          1.0       0.89      0.90      0.90      7127
#
#     accuracy                           0.90     14175
#    macro avg       0.90      0.90      0.90     14175
# weighted avg       0.90      0.90      0.90     14175

# %%
#My accuracy for this model is 90%

# %%
#Checking accuracy for logistic regression model

LR=LogisticRegression()
LR.fit(x_train,y_train)
predLR=LR.predict(x_test)
print(accuracy_score(y_test,predLR))
print(confusion_matrix(y_test,predLR))
print(classification_report(y_test,predLR))
# Out:
# 0.7274779541446208
# [[5019 2029]
#  [1834 5293]]
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.71      0.72      7048
#          1.0       0.72      0.74      0.73      7127
#
#     accuracy                           0.73     14175
#    macro avg       0.73      0.73      0.73     14175
# weighted avg       0.73      0.73      0.73     14175

# %%
#My accuracy for this model is 73%

# %%
#Checking accuracy for support vector machine classifier

svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.8122751322751323
# [[5302 1746]
#  [ 915 6212]]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.75      0.80      7048
#          1.0       0.78      0.87      0.82      7127
#
#     accuracy                           0.81     14175
#    macro avg       0.82      0.81      0.81     14175
# weighted avg       0.82      0.81      0.81     14175

# %%
#My accuracy for this model is 81%

# %%
#Checking accuracy for Gradient Boosting Classifier

GB=GradientBoostingClassifier()
GB.fit(x_train,y_train)
predGB=GB.predict(x_test)
print(accuracy_score(y_test,predGB))
print(confusion_matrix(y_test,predGB))
print(classification_report(y_test,predGB))
# Out:
# 0.8636331569664903
# [[5914 1134]
#  [ 799 6328]]
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.84      0.86      7048
#          1.0       0.85      0.89      0.87      7127
#
#     accuracy                           0.86     14175
#    macro avg       0.86      0.86      0.86     14175
# weighted avg       0.86      0.86      0.86     14175

# %%
#My accuracy for this model is 86%

# %%
#Checking accuracy for Ada Boost Classifier

ABC=AdaBoostClassifier()
ABC.fit(x_train,y_train)
predABC=ABC.predict(x_test)
print(accuracy_score(y_test,predABC))
print(confusion_matrix(y_test,predABC))
print(classification_report(y_test,predABC))
# Out:
# 0.8493827160493828
# [[5908 1140]
#  [ 995 6132]]
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.84      0.85      7048
#          1.0       0.84      0.86      0.85      7127
#
#     accuracy                           0.85     14175
#    macro avg       0.85      0.85      0.85     14175
# weighted avg       0.85      0.85      0.85     14175

# %%
#My accuracy for this model is 85%

# %%
#Checking accuracy for Bagging Classifier

BC=BaggingClassifier()
BC.fit(x_train,y_train)
predBC=BC.predict(x_test)
print(accuracy_score(y_test,predBC))
print(confusion_matrix(y_test,predBC))
print(classification_report(y_test,predBC))
# Out:
# 0.8788712522045855
# [[6287  761]
#  [ 956 6171]]
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.89      0.88      7048
#          1.0       0.89      0.87      0.88      7127
#
#     accuracy                           0.88     14175
#    macro avg       0.88      0.88      0.88     14175
# weighted avg       0.88      0.88      0.88     14175

# %%
#My accuracy for this model is 88%

# %%
#Checking accuracy for ExtraTrees Classifier

ET=ExtraTreesClassifier()
ET.fit(x_train,y_train)
predET=ET.predict(x_test)
print(accuracy_score(y_test,predET))
print(confusion_matrix(y_test,predET))
print(classification_report(y_test,predET))
# Out:
# 0.9001763668430335
# [[6290  758]
#  [ 657 6470]]
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.89      0.90      7048
#          1.0       0.90      0.91      0.90      7127
#
#     accuracy                           0.90     14175
#    macro avg       0.90      0.90      0.90     14175
# weighted avg       0.90      0.90      0.90     14175

# %%
#My accuracy for this model is 90%

# %% [markdown]
# #### Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
#Checking cv score for Random Forest Classifier

score=cross_val_score(RFC,x,y) 
print(score)  
print(score.mean())   
print("Difference between Accuracy score and Cross validation score is:",accuracy_score(y_test,predRFC)-score.mean())
# Out:
# [0.74126984 0.8637037  0.91989418 0.9221164  0.92095238]
# 0.8735873015873015
# Difference between Accuracy score and Cross validation score is: 0.022074074074074246

# %%
#Checking cv score for Logistic Regression

score=cross_val_score(LR,x,y)  
print(score)
print(score.mean())   
print("Difference between Accuracy score and Cross validation score is:",accuracy_score(y_test,predLR)-score.mean())
# Out:
# [0.67216931 0.72042328 0.74021164 0.73925926 0.74507937]
# 0.7234285714285714
# Difference between Accuracy score and Cross validation score is: 0.004049382716049377

# %%
#Checking cv score for Gradient Boosting Classifier

score=cross_val_score(GB,x,y)  
print(score)
print(score.mean())   
print("Difference between Accuracy score and Cross validation score is:",accuracy_score(y_test,predGB)-score.mean())
# Out:
# [0.74677249 0.84243386 0.87037037 0.88137566 0.87534392]
# 0.8432592592592592
# Difference between Accuracy score and Cross validation score is: 0.020373897707231192

# %%
#Checking cv score for Support Vector Machine Classifier

score=cross_val_score(svc,x,y)  
print(score)
print(score.mean())   
print("Difference between Accuracy score and Cross validation score is:",accuracy_score(y_test,predsvc)-score.mean())
# Out:
# [0.76179894 0.80169312 0.81312169 0.8210582  0.81820106]
# 0.8031746031746032
# Difference between Accuracy score and Cross validation score is: 0.009100529100529053

# %%
#Checking cv score for Ada Boosting Classifier

score=cross_val_score(ABC,x,y)  
print(score)
print(score.mean())   
print("Difference between Accuracy score and Cross validation score is:",accuracy_score(y_test,predABC)-score.mean())
# Out:
# [0.7437037  0.83407407 0.85439153 0.86677249 0.85883598]
# 0.8315555555555555
# Difference between Accuracy score and Cross validation score is: 0.017827160493827265

# %%
#Checking cv score for Bagging Classifier

score=cross_val_score(BC,x,y)  
print(score)
print(score.mean())   
print("Difference between Accuracy score and Cross validation score is:",accuracy_score(y_test,predBC)-score.mean())
# Out:
# [0.71386243 0.85026455 0.91121693 0.91597884 0.91428571]
# 0.8611216931216932
# Difference between Accuracy score and Cross validation score is: 0.01774955908289233

# %%
#Checking cv score for Extra Trees Classifier

score=cross_val_score(ET,x,y)  
print(score)
print(score.mean())   

print("Difference between Accuracy score and Cross validation score is:",accuracy_score(y_test,predET)-score.mean())
# Out:
# [0.76772487 0.87619048 0.92010582 0.92582011 0.92349206]
# 0.8826666666666666
# Difference between Accuracy score and Cross validation score is: 0.017509700176366882

# %% [markdown]
# #Here the Logistic regression is the best performing model because the Difference between Accuracy score and Cross validation score is the least here.

# %% [markdown]
# #### Hyper Parameter Tuning

# %%
# !pip install sklearn.model

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'penalty':['l1', 'l2', 'elasticnet', None],
           'random_state': [10,50,1000],
           'C':[1.0,2.0,3.0],
           'n_jobs':[-2,-1,1],
           'dual':[True,False]}

# %%
GCV=GridSearchCV(LogisticRegression(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [1.0, 2.0, 3.0], 'dual': [True, False],
#                          'n_jobs': [-2, -1, 1],
#                          'penalty': ['l1', 'l2', 'elasticnet', None],
#                          'random_state': [10, 50, 1000]})

# %%
GCV.best_params_
# Out:
# {'C': 1.0, 'dual': False, 'n_jobs': -2, 'penalty': 'l2', 'random_state': 10}

# %%
Final_model=LogisticRegression(C= 1.0, dual= False, n_jobs= -2, penalty= 'l2', random_state= 10)
Final_model.fit(x_train,y_train)
pred=Final_model.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 72.74779541446208

# %% [markdown]
# #### Plotting ROC AUC curve

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
y_pred_prob=Final_model.predict_proba(x_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
roc_auc=auc(fpr,tpr)

plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label="LogisticRegression(area=%0.2f)"% roc_auc)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.show()
auc_score=roc_auc_score(y_test,Final_model.predict(x_test))
print("AUC score:","\n",auc_score)
# Out:
# AUC score:
#  0.7273928185839306

# %%
#Saving the model using .pkl

import joblib
joblib.dump(Final_model,"Census.pkl")
# Out:
# ['Census.pkl']

# %%
#Lets load the saved model and get the predictions

model=joblib.load("Census.pkl")


#Prediction
prediction=model.predict(x_test)
prediction
# Out:
# array([1., 0., 1., ..., 1., 0., 1.])

# %%
#These are the income predictions
