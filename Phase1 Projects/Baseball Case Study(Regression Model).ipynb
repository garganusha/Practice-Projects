# %% [markdown]
# ### Baseball Case Study

# %%
#Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Load the dataset

df=pd.read_csv('C:/Users/HP/OneDrive/Desktop/Baseball.csv')
df
# Out:
#      W    R   AB     H    2B   3B  HR   BB   SO    SB   RA   ER  ERA    CG  \
# 0    2   95  724  5575  1497  300  42  139  383   973  104  641  601  3.73
# 1    3   83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07
# 2    4   81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67
# 3    5   76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98
# 4    6   74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64
# 5    7   93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80
# 6    8   87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03
# 7    9   81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05
# 8   10   80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74
# 9   11   78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31
# 10  12   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24
# ...

# %%
df.head()   #First 5 rows
# Out:
#    W   R   AB     H    2B   3B  HR   BB   SO    SB   RA   ER  ERA    CG  SHO  \
# 0  2  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73    2
# 1  3  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07    2
# 2  4  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67   11
# 3  5  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98    7
# 4  6  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64    7
#
#    SV   E  Unnamed: 17
# 0   8  56           88
# 1  12  45           86
# 2  10  38           79
# 3   9  37          101
# 4  12  35           86

# %%
df.tail()   #last 5 rows
# Out:
#      W   R   AB     H    2B   3B  HR   BB   SO    SB   RA   ER  ERA    CG  \
# 25  27  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44
# 26  28  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72
# 27  29  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04
# 28  30  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09
# 29  31  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04
#
#     SHO  SV   E  Unnamed: 17
# 25    6  21  47           75
# 26    7  18  41           78
# 27    1  12  44           86
# 28    1   6  41           92
# 29    4   4  36           95

# %%
df.shape  #Dimension of data
# Out:
# (30, 18)

# %%
df.columns.to_list()   #All the columns present
# Out:
# ['W',
#  'R',
#  'AB',
#  'H',
#  '2B',
#  '3B',
#  'HR',
#  'BB',
#  'SO',
#  'SB',
#  'RA',
#  'ER',
#  'ERA',
#  'CG',
#  'SHO',
#  'SV',
#  'E',
#  'Unnamed: 17']

# %%
df.dtypes  #Data type of each column
# Out:
# W                int64
# R                int64
# AB               int64
# H                int64
# 2B               int64
# 3B               int64
# HR               int64
# BB               int64
# SO               int64
# SB               int64
# RA               int64
# ER               int64
# ERA              int64
# CG             float64
# SHO              int64
# SV               int64
# E                int64
# Unnamed: 17      int64
# dtype: object

# %%
#We can see float and int data types of the columns

# %%
df.isnull().sum()  #Sum of all the null values in each column
# Out:
# W              0
# R              0
# AB             0
# H              0
# 2B             0
# 3B             0
# HR             0
# BB             0
# SO             0
# SB             0
# RA             0
# ER             0
# ERA            0
# CG             0
# SHO            0
# SV             0
# E              0
# Unnamed: 17    0
# dtype: int64

# %%
#We can see there are no null values in any column

# %%
df.isnull().sum().sum()  #Total null values in the entire dataset
# Out:
# 0

# %%
df.info()  #Gives the non null count and dtype information of all the columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   W            30 non-null     int64
#  1   R            30 non-null     int64
#  2   AB           30 non-null     int64
#  3   H            30 non-null     int64
#  4   2B           30 non-null     int64
#  5   3B           30 non-null     int64
#  6   HR           30 non-null     int64
#  7   BB           30 non-null     int64
#  8   SO           30 non-null     int64
#  9   SB           30 non-null     int64
#  10  RA           30 non-null     int64
#  11  ER           30 non-null     int64
#  12  ERA          30 non-null     int64
#  13  CG           30 non-null     float64
#  14  SHO          30 non-null     int64
#  15  SV           30 non-null     int64
#  16  E            30 non-null     int64
#  17  Unnamed: 17  30 non-null     int64
# dtypes: float64(1), int64(17)
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
#Entire heatmap is of same colour as there are no null values

# %%
#Checking number of unique values in each column
df.nunique().to_frame("No. of unique values")
# Out:
#              No. of unique values
# W                              30
# R                              24
# AB                             28
# H                              29
# 2B                             29
# 3B                             22
# HR                             23
# BB                             27
# SO                             29
# SB                             29
# RA                             27
# ER                             30
# ERA                            30
# CG                             30
# SHO                             9
# SV                             12
# E                              20
# Unnamed: 17                    21

# %%
#checking the value counts of unique values in each column

for i in df.columns:
    print(df[i].value_counts())
    print('\n')  #new line
# Out:
# 2     1
# 3     1
# 30    1
# 29    1
# 28    1
# 27    1
# 26    1
# 25    1
# 24    1
# 23    1
# 22    1
# 21    1
# 20    1
# 19    1
# 18    1
# 17    1
# 16    1
# 15    1
# 14    1
# 13    1
# 12    1
# 11    1
# 10    1
# 9     1
# 8     1
# 7     1
# 6     1
# 5     1
# 4     1
# 31    1
# Name: W, dtype: int64
#
#
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: R, dtype: int64
#
#
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: AB, dtype: int64
#
#
# 5485    2
# 5575    1
# 5631    1
# ...

# %% [markdown]
# #The column 'Unnamed: 17' is an additional column present in the dataset. It appears to be an extra column that does not have a specific label or purpose.
#
# In this case, since the 'Unnamed: 17' column does not provide any meaningful information and contains no label or description, it can be safely dropped from the dataset.

# %%
df.drop("Unnamed: 17",axis=1,inplace=True)

# %%
df
# Out:
#      W    R   AB     H    2B   3B  HR   BB   SO    SB   RA   ER  ERA    CG  \
# 0    2   95  724  5575  1497  300  42  139  383   973  104  641  601  3.73
# 1    3   83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07
# 2    4   81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67
# 3    5   76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98
# 4    6   74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64
# 5    7   93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80
# 6    8   87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03
# 7    9   81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05
# 8   10   80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74
# 9   11   78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31
# 10  12   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24
# ...

# %% [markdown]
# ### Checking deplicate rows

# %%
print("Total duplicate rows are:",df.duplicated().sum())   #THis function is used to check the duplicate rows in the df
# Out:
# Total duplicate rows are: 0

# %%
df.describe()   #Statistical description of the dataset
# Out:
#                W           R          AB            H           2B  \
# count  30.000000   30.000000   30.000000    30.000000    30.000000
# mean   16.500000   80.966667  688.233333  5516.266667  1403.533333
# std     8.803408   10.453455   58.761754    70.467372    57.140923
# min     2.000000   63.000000  573.000000  5385.000000  1324.000000
# 25%     9.250000   74.000000  651.250000  5464.000000  1363.000000
# 50%    16.500000   81.000000  689.000000  5510.000000  1382.500000
# 75%    23.750000   87.750000  718.250000  5570.000000  1451.500000
# max    31.000000  100.000000  891.000000  5649.000000  1515.000000
#
#                3B         HR          BB          SO          SB          RA  \
# count   30.000000  30.000000   30.000000   30.000000    30.00000   30.000000
# mean   274.733333  31.300000  163.633333  469.100000  1248.20000   83.500000
# std     18.095405  10.452355   31.823309   57.053725   103.75947   22.815225
# ...

# %%
#if mean>median its right skewed i.e. in H, 2B, BB, E
#if mean<median its left skewed i.e. in R, AB
#max value is high than the 75% data i.e. outliers are present

# %%
#Plotting on a heatmap

plt.figure(figsize=(22,10))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linewidth=1,linecolor='black',cmap='Spectral')
plt.xlabel('Figure',fontsize=14)
plt.ylabel("Features_name",fontsize=14)
plt.title("Descriptive Graph",fontsize=20)
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
#Creating lmplot of all the the feature variable with the label variable

sns.lmplot(x='R',y='W',data=df)

# %%
#Runs Scored(R) is negative linear correlated to Wins

# %%
sns.lmplot(x='AB',y='W',data=df)

# %%
#At Bat is negatively linear correlated to the Wins

# %%
sns.lmplot(x='H',y='W',data=df)

# %%
#Hits are weakly correlated to Wins

# %%
sns.lmplot(x='2B',y='W',data=df)

# %%
#2B is also weakly correlated to the Wins

# %%
sns.lmplot(x='3B',y='W',data=df)

# %%
#Triples are negatively correlated to the Wins

# %%
sns.lmplot(x='HR',y='W',data=df)

# %%
#Home Runs are lightly correlated to the Wins

# %%
sns.lmplot(x='BB',y='W',data=df)

# %%
#Base on Balls is negatively correlated to the Wins

# %%
sns.lmplot(x='SO',y='W',data=df)

# %%
#StrikeOut is very weakly correlated to the Wins

# %%
sns.lmplot(x='SB',y='W',data=df)

# %%
#Stolen Base is positively correlated to the Wins

# %%
sns.lmplot(x='RA',y='W',data=df)

# %%
#Run Average is lightly positive correlated to the Wins

# %%
sns.lmplot(x='ERA',y='W',data=df)

# %%
#ERA is lightly positive correlated to the Wins

# %%
sns.lmplot(x='CG',y='W',data=df)

# %%
#CG is lightly positive correlated to the Wins

# %%
sns.lmplot(x='SHO',y='W',data=df)

# %%
#SHO is negatively correlated to the Wins

# %%
sns.lmplot(x='SV',y='W',data=df)

# %%
#SV is weakly positive correlated to the Wins

# %%
sns.lmplot(x='E',y='W',data=df)

# %%
#Errors is negatively correlated to the Wins

# %%
#Plotting regression plot

plt.figure(figsize=(20,15))
p=1
for i in df.columns:
    if p<=30:    
        plt.subplot(5,6,p)
        sns.regplot(x=df['W'],y=i,data=df,color='r')
        plt.xlabel("Wins")
        plt.ylabel(i)
    p+=1
plt.show()

# %%
#Plotting scatter plot

plt.figure(figsize=(20,15))
p=1
for i in df.columns:
    if p<=30:    
        plt.subplot(5,6,p)
        sns.scatterplot(x=df['W'],y=i,data=df,color='r')
        plt.xlabel("Wins")
        plt.ylabel(i)
    p+=1
plt.show()

# %% [markdown]
# #From all these figures we can conclude that no feature variable has a high positive relationship withe the target variable

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(data=df,palette='Dark2')

# %%
#Let's check the outliers by plotting the boxplot

plt.figure(figsize=(25,25))
p=1
for i in df.columns:
    if p<=30:
        plt.subplot(5,6,p)
        sns.boxplot(df[i],palette="Set2_r")
        plt.xlabel(i)
    p+=1
plt.show()

# %%
#We can see outliers in AB,CG,SV,E

# %%
#Using Z score method to remove the outliers

from scipy.stats import zscore
out_features=df[['AB','CG','SV','E']]
z=np.abs(zscore(out_features))  
z
# Out:
#           AB        CG        SV         E
# 0   0.619078  0.506955  0.814629  1.671607
# 1   0.134432  0.254598  0.172800  0.249879
# 2   0.332906  0.641347  0.320914  0.654856
# 3   1.146419  0.053010  0.567771  0.784104
# 4   0.013270  1.531318  0.172800  1.042600
# 5   3.509647  0.350165  0.320914  1.171848
# 6   1.311430  0.165003  1.802057  0.637623
# 7   0.428681  0.209800  0.320914  0.008617
# 8   0.765626  0.484557  0.172800  2.188598
# 9   1.034489  0.792164  0.320914  0.396360
# 10  1.086415  0.635374  0.567771  0.249879
# 11  0.705622  0.865333  0.419657  0.525608
# 12  0.471376  0.036584  0.172800  0.379127
# 13  0.557920  0.456185  0.172800  0.249879
# 14  0.099814  0.411388  0.913371  1.947335
# 15  0.713699  2.276445  0.913371  2.447094
# 16  0.151740  1.671683  0.419657  1.413111
# 17  0.013270  1.335704  2.394514  0.637623
# 18  0.575229  0.724968  1.061486  0.396360
# 19  0.834861  0.836961  0.814629  1.042600
# 20  0.090583  1.178913  0.666514  0.896119
# ...

# %%
#threshold=3

np.where(z>3)  #These are where the outliers are present
# Out:
# (array([5], dtype=int64), array([0], dtype=int64))

# %%
#Now removing the data above Z score and creating a new df

df1=df[(z<3).all(axis=1)]  
df1
# Out:
#      W    R   AB     H    2B   3B  HR   BB   SO    SB   RA   ER  ERA    CG  \
# 0    2   95  724  5575  1497  300  42  139  383   973  104  641  601  3.73
# 1    3   83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07
# 2    4   81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67
# 3    5   76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98
# 4    6   74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64
# 6    8   87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03
# 7    9   81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05
# 8   10   80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74
# 9   11   78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31
# 10  12   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24
# 11  13   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57
# ...

# %%
print("Old dataframe",df.shape[0])  #df.shape[0] will give only the rows
print("New dataframe",df1.shape[0])
# Out:
# Old dataframe 30
# New dataframe 29

# %%
#Checking the data loss percentage after removing the outliers

print("Data Loss Percentage:", ((df.shape[0]-df1.shape[0])/df.shape[0])*100)    #Change in data/original data *100
# Out:
# Data Loss Percentage: 3.3333333333333335

# %%
#Now lets check with IQR method:

#1st Quantile
Q1=out_features.quantile(0.25)

#3rd Quantile
Q3=out_features.quantile(0.75)

IQR=Q3-Q1

df2=df[~((df < (Q1-1.5*IQR))|(df> (Q3+ 1.5*IQR))).any(axis=1)]

# %%
df2
# Out:
#      W   R   AB     H    2B   3B  HR   BB   SO    SB   RA   ER  ERA    CG  \
# 0    2  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73
# 1    3  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07
# 2    4  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67
# 3    5  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98
# 4    6  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64
# 6    8  87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03
# 7    9  81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05
# 8   10  80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74
# 9   11  78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31
# 10  12  88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24
# 11  13  86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57
# 12  14  85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94
# ...

# %%
print("Data Loss Percentage:", ((df.shape[0]-df2.shape[0])/df.shape[0])*100)    #Change in data/original data *100
# Out:
# Data Loss Percentage: 16.666666666666664

# %%
#We will choose z score method as its giving less data loss comparatively.

# %%
df=df1

# %%
df
# Out:
#      W    R   AB     H    2B   3B  HR   BB   SO    SB   RA   ER  ERA    CG  \
# 0    2   95  724  5575  1497  300  42  139  383   973  104  641  601  3.73
# 1    3   83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07
# 2    4   81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67
# 3    5   76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98
# 4    6   74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64
# 6    8   87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03
# 7    9   81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05
# 8   10   80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74
# 9   11   78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31
# 10  12   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24
# 11  13   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57
# ...

# %% [markdown]
# ### Checking how the data is distributed in each column

# %%
plt.figure(figsize=(20,25),facecolor='green')
plotnumber=1

for i in df.columns:   
    if plotnumber<=30:
        plt.subplot(6,5,plotnumber)
        sns.distplot(df[i],color='m')
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.show()

# %%
#From the above dist plots we can see that data is almost normally distributed in all the columns

# %%
#Checking skewness


df.skew()
# Out:
# W     -0.071663
# R      0.119013
# AB    -0.215364
# H      0.169573
# 2B     0.783772
# 3B    -0.335304
# HR     0.090124
# BB     0.450862
# SO     0.151193
# SB    -0.233815
# RA     0.494966
# ER     0.018155
# ERA    0.018461
# CG     0.016693
# SHO    0.854980
# SV     0.526943
# E      0.627480
# dtype: float64

# %%
#We can see little high skewness in 2B and SHO

# %%
import scipy.stats as stats
import math

# %%
#Removing skewness by yeojohnson(modified version of box-cox)
df['2B']=np.cbrt(df['2B'])
df['SHO']=np.sqrt(df['SHO'])

# %%
df.skew()
# Out:
# W     -0.071663
# R      0.119013
# AB    -0.215364
# H      0.169573
# 2B     0.753696
# 3B    -0.335304
# HR     0.090124
# BB     0.450862
# SO     0.151193
# SB    -0.233815
# RA     0.494966
# ER     0.018155
# ERA    0.018461
# CG     0.016693
# SHO   -0.260678
# SV     0.526943
# E      0.627480
# dtype: float64

# %%
#Skewness is reduced

# %%
#Let's visualize again

plt.figure(figsize=(20,25),facecolor='green')
plotnumber=1

for i in df.columns:   
    if plotnumber<=25:
        plt.subplot(6,4,plotnumber)
        sns.distplot(df[i],color='m')
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.show()

# %%
#Data is almost normally distributed in all the variables

# %%
#Now we will check correlation with feature variables

df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000 -0.264776 -0.242186 -0.067147 -0.074561 -0.252293  0.055063
# R   -0.264776  1.000000  0.390451 -0.085780 -0.019968  0.384886 -0.206737
# AB  -0.242186  0.390451  1.000000  0.438022  0.432686  0.469293  0.134204
# H   -0.067147 -0.085780  0.438022  1.000000  0.769847  0.490752  0.445604
# 2B  -0.074561 -0.019968  0.432686  0.769847  1.000000  0.527588  0.580521
# 3B  -0.252293  0.384886  0.469293  0.490752  0.527588  1.000000  0.342419
# HR   0.055063 -0.206737  0.134204  0.445604  0.580521  0.342419  1.000000
# BB  -0.155937  0.245697  0.586894 -0.064653 -0.219048 -0.098695 -0.369299
# SO   0.006108  0.447513  0.258450 -0.137850 -0.221951  0.211243 -0.404852
# SB   0.236195  0.156469  0.081158 -0.111243 -0.372834 -0.096772 -0.196586
# RA   0.199479 -0.169503  0.075323  0.373674  0.419443  0.194308  0.483818
# ER   0.112560 -0.823176 -0.013858  0.315499  0.243965 -0.215196  0.312750
# ...

# %%
#Visualizing it on the heatmap

plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,fmt='0.2f',linewidth=1,linecolor='black',cmap="Blues")
plt.xlabel("Figure")
plt.ylabel("Features name")
plt.title("Descriptive Graph")
plt.show()

# %% [markdown]
#  We can see many  independent variables ER,ERA and CG have almost perfect correlation with each other so there's a problem of multicolliniarity.

# %%
#Checking the correlation of target variable only

df.corr()['W'].sort_values(ascending=False)
# Out:
# W      1.000000
# SB     0.236195
# RA     0.199479
# SV     0.132032
# ER     0.112560
# CG     0.106120
# ERA    0.097385
# HR     0.055063
# SO     0.006108
# H     -0.067147
# 2B    -0.074561
# BB    -0.155937
# E     -0.179767
# SHO   -0.197619
# AB    -0.242186
# 3B    -0.252293
# R     -0.264776
# Name: W, dtype: float64

# %%
#All the features are very less correlated with the target variable i.e they are contributing too less in it's prediction.

# %%
#Visualizing the correlation between the features and the label using bar plot

plt.figure(figsize=(22,7))
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='g')
plt.title("Correlation between features and label using bar plot",fontsize=20)
plt.xlabel("Features")
plt.ylabel("Target variable")
plt.show()

# %% [markdown]
# ### Seperating features and label

# %%
x=df.drop(['W'],axis=1)
y=df["W"]

# %%
print("Feature dimensions:",x.shape)
print("Target dimensions:",y.shape)
# Out:
# Feature dimensions: (29, 16)
# Target dimensions: (29,)

# %% [markdown]
# ### Feature scaling using Standard Scalarization

# %%
#To remove the biasness

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   1.416025  0.959398  0.830084  1.728647  1.556538  1.010845 -0.765863
# 1   0.239947  0.331147 -0.702831 -0.946162  0.201171  1.208917 -0.181389
# 2   0.043934 -0.274666 -1.100253 -0.094708  1.733325 -0.276617 -0.697101
# 3  -0.446099 -1.329231  0.233951 -0.351839 -0.800621 -0.474688 -0.869006
# 4  -0.642112  0.174084  1.255894  2.041742  0.908319  1.704094 -0.353293
# 5   0.631973  1.856900  0.716535 -0.058116 -0.093474 -1.266972  1.743939
# 6   0.043934  0.712585 -0.447345 -0.555092 -1.625627 -1.167936  1.915843
# 7  -0.054073 -0.835605 -0.447345 -0.315000  0.260100  0.020490  0.196801
# 8  -0.250086  1.497899  1.752672  1.693704  1.202964  0.119526 -0.009484
# 9   0.729980  1.565212 -0.078310  0.342114  0.319029  0.020490  0.368705
# 10  0.533967  1.071586 -0.816380 -0.685001  0.260100 -0.573723  2.362794
# 11  0.435960 -0.454167 -1.412514 -1.284608 -1.802414 -1.068901  0.506228
# ...

# %% [markdown]
# ### Checking Variance Inflation Factor

# %%
#Checking Vif in every scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#      VIF values Features
# 0     19.611684        R
# 1     13.800297       AB
# 2     17.810304        H
# 3      7.781979       2B
# 4      4.226265       3B
# 5      3.228387       HR
# 6      8.019392       BB
# 7      3.875535       SO
# 8      2.744206       SB
# 9      2.002128       RA
# 10   195.707525       ER
# 11  1831.326024      ERA
# 12  1643.224568       CG
# 13     3.213233      SHO
# 14     3.801732       SV
# 15     7.367256        E

# %%
#We can see the problem of high VIF in ER,ERA and CG

# %%
#Dropping column with highest VIF

x.drop("ERA",axis=1,inplace=True)

# %%
#again checking VIF

#Checking Vif in every scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#     VIF values Features
# 0    18.124416        R
# 1    10.980380       AB
# 2     7.425210        H
# 3     7.434379       2B
# 4     4.136409       3B
# 5     3.206233       HR
# 6     6.355644       BB
# 7     3.815092       SO
# 8     2.735259       SB
# 9     1.846793       RA
# 10  163.893170       ER
# 11  188.763350       CG
# 12    3.141144      SHO
# 13    3.772560       SV
# 14    6.474208        E

# %%
#Dropping CG as well as the vif is very high

x.drop("CG",axis=1,inplace=True)

# %%
#again checking VIF

#Checking Vif in every scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#     VIF values Features
# 0    13.477840        R
# 1    10.051927       AB
# 2     3.602480        H
# 3     5.067718       2B
# 4     3.783535       3B
# 5     3.124442       HR
# 6     5.587972       BB
# 7     3.178117       SO
# 8     2.285500       SB
# 9     1.841950       RA
# 10    8.972949       ER
# 11    2.908725      SHO
# 12    3.555639       SV
# 13    5.208807        E

# %%
#Dropping R as well as the vif is higher than 10

x.drop("R",axis=1,inplace=True)

# %%
#Checking Vif in every scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#     VIF values Features
# 0     5.174739       AB
# 1     3.587367        H
# 2     5.035263       2B
# 3     3.473530       3B
# 4     3.089948       HR
# 5     4.552878       BB
# 6     3.088631       SO
# 7     2.143063       SB
# 8     1.816564       RA
# 9     5.114497       ER
# 10    2.486533      SHO
# 11    3.439042       SV
# 12    2.503164        E

# %%
#VIF of all the features are under control now which means multicolliniarity is solved

# %% [markdown]
# ### Modelling

# %%
#Importing libraries

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
#Importing all the regressor models

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %% [markdown]
# ### Creating train test split

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum R2 score is:",maxAccu,"on random state",maxRS)
# Out:
# Maximum R2 score is: 0.38485383062336753 on random state 27

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
#Importing all the regressor models

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_LR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score: 0.38485383062336753
# R2 score on training data: 24.95202611051488
# Mean Absolute Error: 4.569347216669166
# Mean Squared Error: 25.350097696039498
# Root Mean Squared Error: 5.0348880519868064

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_RFR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_RFR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2 score: -0.5530095865787896
# R2 score on training data: 82.10662689111443
# Mean Absolute Error: 6.5
# Mean Squared Error: 63.99933333333334
# Root Mean Squared Error: 7.999958333224826

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print("R2 score:",r2_score(y_test,pred_knn))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error:",mean_squared_error(y_test,pred_knn))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2 score: -0.24587177950868777
# R2 score on training data: 12.8550120239871
# Mean Absolute Error: 6.044444444444445
# Mean Squared Error: 51.342222222222226
# Root Mean Squared Error: 7.165348716023682

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_GBR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_GBR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2 score: -1.0776261296388778
# R2 score on training data: 99.99998927663725
# Mean Absolute Error: 7.960384498911101
# Mean Squared Error: 85.61871630536513
# Root Mean Squared Error: 9.253038220247722

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print("R2 score:",r2_score(y_test,pred_lasso))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error:",mean_squared_error(y_test,pred_lasso))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2 score: -0.5167119890419059
# R2 score on training data: 12.082307477332533
# Mean Absolute Error: 6.727698701554672
# Mean Squared Error: 62.50351382002324
# Root Mean Squared Error: 7.9059163807887085

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print("R2 score:",r2_score(y_test,pred_rd))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_rd))
print("Mean Squared Error:",mean_squared_error(y_test,pred_rd))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2 score: 0.331172089441396
# R2 score on training data: 24.498082190338245
# Mean Absolute Error: 4.634705935116181
# Mean Squared Error: 27.56231562277309
# Root Mean Squared Error: 5.249982440234738

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_train=dtr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_dtr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_dtr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_dtr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2 score: -4.079688436189334
# R2 score on training data: 100.0
# Mean Absolute Error: 12.444444444444445
# Mean Squared Error: 209.33333333333334
# Root Mean Squared Error: 14.46835627614047

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_svr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_svr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_svr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# R2 score: -0.4100859927871252
# R2 score on training data: 11.76391137858771
# Mean Absolute Error: 6.668960854093616
# Mean Squared Error: 58.10946967806697
# Root Mean Squared Error: 7.622956754309116

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_etr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_etr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_etr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# R2 score: -1.1157921509886157
# R2 score on training data: 100.0
# Mean Absolute Error: 7.342222222222222
# Mean Squared Error: 87.19153333333333
# Root Mean Squared Error: 9.337640672746694

# %%
from sklearn.model_selection import cross_val_score

# %%
#Checking cvs for every model
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [ -91.98487596  -43.41988956  -15.87487164 -188.52395361 -185.68884772]
# -105.09848769603407
# Difference between R2 score and CVS is: 10548.334152665744

# %%
score=cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [-6.76735529e+01 -1.33356629e+01 -7.25428571e-02 -3.42803257e+01
#  -1.25698820e+02]
# -48.212180857142855
# Difference between R2 score and CVS is: 4765.917127056407

# %%
score=cross_val_score(knn,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_knn)-score.mean())*100)
# Out:
# [ -63.224       -18.52457143   -2.49942857  -22.45371429 -115.392     ]
# -44.41874285714286
# Difference between R2 score and CVS is: 4417.287107763417

# %%
score=cross_val_score(GBR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [ -68.81254811  -16.23473458   -1.35883798  -47.25401908 -141.78292342]
# -55.08861263456161
# Difference between R2 score and CVS is: 5401.098650492273

# %%
score=cross_val_score(lasso,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_lasso)-score.mean())*100)
# Out:
# [ -67.30197904  -24.45071765   -0.66331021  -30.58869242 -138.80591257]
# -52.362122379312474
# Difference between R2 score and CVS is: 5184.541039027056

# %%
score=cross_val_score(rd,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_rd)-score.mean())*100)
# Out:
# [ -79.71419803  -36.75215102   -8.89158003  -83.9318843  -175.79798608]
# -77.01755989050238
# Difference between R2 score and CVS is: 7734.873197994378

# %%
score=cross_val_score(dtr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_dtr)-score.mean())*100)
# Out:
# [ -74.51428571  -27.4         -39.34285714  -67.51428571 -125.2       ]
# -66.79428571428572
# Difference between R2 score and CVS is: 6271.459727809638

# %%
score=cross_val_score(svr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_svr)-score.mean())*100)
# Out:
# [ -55.44778057  -20.36762639   -4.06860473  -28.33803416 -103.92663662]
# -42.42973649441283
# Difference between R2 score and CVS is: 4201.96505016257

# %%
score=cross_val_score(etr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_etr)-score.mean())*100)
# Out:
# [ -74.35804143  -14.15098857   -1.80574286  -30.53861143 -129.13176   ]
# -49.99702885714286
# Difference between R2 score and CVS is: 4888.123670615424

# %% [markdown]
# #In all the models the difference is coming very high it means there is over fitting problem. Which means that the model is performing well on the training data but not very well on the unseen data.

# %% [markdown]
# #From the difference we conclude svr has the lowest difference but its r2 score is negative so we will go ahead with ridge

# %% [markdown]
# ### HyperParameter tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge

# %%
param = {'alpha': [0.1, 1, 10],
    'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg'],
    'fit_intercept': [True, False],'random_state':[1,4,10,20]}

# %%
gscv=GridSearchCV(Ridge(),param,cv=5)

# %%
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [0.1, 1, 10], 'fit_intercept': [True, False],
#                          'random_state': [1, 4, 10, 20],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                     'sparse_cg']})

# %%
gscv.best_params_
# Out:
# {'alpha': 10, 'fit_intercept': True, 'random_state': 1, 'solver': 'lsqr'}

# %%
Model=Ridge(alpha= 10,fit_intercept= True,solver= 'lsqr',random_state=1)

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print("R2 score:",r2_score(y_test,pred))
print("Mean Absolute Error:",mean_absolute_error(y_test,pred))
print("Mean Squared Error:",mean_squared_error(y_test,pred))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 score: 0.010531831675573478
# Mean Absolute Error: 5.383411852735803
# Mean Squared Error: 40.77586106008563
# Root Mean Squared Error: 6.3855979406854

# %%
#As we can see that hyperparameter tuning is further degrading the model, we will go with the original model

# %%
import pickle
filename='Baseball.pkl'
pickle.dump(rd,open(filename, 'wb'))  #saved model

# %%
#loading the model

loaded_model=pickle.load(open('Baseball.pkl','rb'))  #read binary mode
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 33.1172089441396

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","original"])   #using[:] to get all the values of predicted data and actual data
conclusion
# Out:
#                    0          1          2          3          4         5  \
# Predicted  19.689187  14.509546  18.687277  15.993489  17.874045  23.40851
# original   18.000000  12.000000  25.000000  23.000000  10.000000  29.00000
#
#                    6          7         8
# Predicted  27.920938  14.391064  19.58315
# original   24.000000  14.000000  26.00000

# %%
#These are the predicted wins of the baseball match
