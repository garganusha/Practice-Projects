# %%
#Importing necessary liabraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing the dataset

df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns.tolist()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
#
#
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
#
#
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: Happiness Rank, Length: 157, dtype: int64
#
#
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# ...

# %%
df.duplicated().sum()   #To check the duplicate rows if any
# Out:
# 0

# %%
#Seperating numerical and categorical columns

categorical_col=[]
for i in df.columns:
    if df.dtypes[i]=='object':
        categorical_col.append(i)
print("Categorical columns are:",categorical_col)
print("\n")

numerical_col=[]
for i in df.columns:
    if df.dtypes[i]!='object':
        numerical_col.append(i)
print("Numerical columns are:",numerical_col)
print("\n")
# Out:
# Categorical columns are: ['Country', 'Region']
#
#
# Numerical columns are: ['Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %%
df.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Rank                   157
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# #Count of all the columns are same i.e. no null values

# %% [markdown]
# #Mean in all the columns is somewhat same to that of median which shows not much skewness

# %%
#Visualize df.describe in a heatmap

plt.figure(figsize=(20,10))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linewidth=1,linecolor='black',cmap='Spectral')
plt.xlabel("Figure")
plt.ylabel("Features name")
plt.title("Descriptive Graph")
plt.show()

# %%
#Creating lmplot of features with label

sns.lmplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df)

# %% [markdown]
# #We can see positive relation between Economy of a country and it's happiness score,but the data is scattered and not on the best fit line

# %%
sns.lmplot(x='Family',y='Happiness Score',data=df)

# %%
sns.lmplot(x='Health (Life Expectancy)',y='Happiness Score',data=df)

# %% [markdown]
# #More the life expectancy and health more is the happiness score of a country

# %%
sns.lmplot(x='Freedom',y='Happiness Score',data=df)

# %%
sns.lmplot(x='Trust (Government Corruption)',y='Happiness Score',data=df)

# %%
sns.lmplot(x='Generosity',y='Happiness Score',data=df)

# %%
sns.lmplot(x='Happiness Rank',y='Happiness Score',data=df)

# %% [markdown]
# #Happiness rank is inversely proportional to Happiness score,i.e. as the rank increases happiness score goes down

# %%
sns.lmplot(x='Standard Error',y='Happiness Score',data=df)

# %% [markdown]
# #There is a positive relation between Generosity and Happiness score but not very strong. The data is not distributed along the line.

# %%
plt.figure(figsize=(22,20))
plotnumber=1
for i in numerical_col:
    if plotnumber<=15:
        plt.subplot(4,3,plotnumber)
        sns.distplot(df[i],color='b')
        plt.xlabel(i)
        plt.yticks(rotation=0)
    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize=(20,15))
p=1
for i in numerical_col:
    if p<=15:    
        plt.subplot(5,3,p) 
        sns.scatterplot(x='Happiness Score',y=i,data=df,color='r')
        plt.xlabel("Happiness Score")
        plt.ylabel(i)
    p+=1
plt.show()

# %%
#Multivariate Analysis

sns.pairplot(data=df,palette='Dark2')

# %%
#Checking for the outliers

plt.figure(figsize=(22,20))
plotnumber=1
for i in numerical_col:
    if plotnumber<=15:
        plt.subplot(5,3,plotnumber)
        sns.boxplot(df[i],palette='bright')
        plt.xlabel(i)
        plt.yticks(rotation=0)
    plotnumber+=1
plt.tight_layout()

# %%
#We can observe outliers in 'Standard error','Family','Trust(Government Corruption)','Generosity' and 'Dystopia Residual'

# %%
#Removing outliers by Z score

from scipy.stats import zscore
out_features=df[['Standard Error','Family','Trust (Government Corruption)','Generosity','Dystopia Residual']]
z=np.abs(zscore(out_features))
z
# Out:
#      Standard Error    Family  Trust (Government Corruption)  Generosity  \
# 0          0.805926  1.320281                       2.309652    0.471040
# 1          0.055889  1.514458                       0.016480    1.575856
# 2          0.854487  1.361054                       2.842774    0.824293
# 3          0.531526  1.251922                       1.852081    0.868638
# 4          0.722845  1.221204                       1.555725    1.748563
# ..              ...       ...                            ...         ...
# 153        0.774917  0.800520                       3.413922    0.087228
# 154        0.662582  2.346860                       0.529210    0.433117
# 155        0.132534  1.901086                       0.381419    1.856891
# 156        2.263962  2.118467                       0.357715    0.316950
# 157        1.134182  3.134725                       0.301803    0.558153
#
#      Dystopia Residual
# 0             0.758258
# 1             1.092857
# ...

# %%
#Threshhold=3

np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([2, 0, 0, 0, 3, 1, 2, 4, 1], dtype=int64))

# %%
#Creating a new df by removing all the data where z>3

df1=df[(z<3).all(axis=1)]
df1
# Out:
#           Country              Region  Happiness Rank  Happiness Score  \
# 0     Switzerland      Western Europe               1            7.587
# 1         Iceland      Western Europe               2            7.561
# 2         Denmark      Western Europe               3            7.527
# 3          Norway      Western Europe               4            7.522
# 4          Canada       North America               5            7.427
# ..            ...                 ...             ...              ...
# 150   Ivory Coast  Sub-Saharan Africa             151            3.655
# 151  Burkina Faso  Sub-Saharan Africa             152            3.587
# 152   Afghanistan       Southern Asia             153            3.575
# 154         Benin  Sub-Saharan Africa             155            3.340
# 156       Burundi  Sub-Saharan Africa             157            2.905
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
print("Old Dataframe",df.shape)
print("New Dataframe",df1.shape)
# Out:
# Old Dataframe (158, 12)
# New Dataframe (149, 12)

# %%
#Data loss %

print("Data loss %=",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data loss %= 5.69620253164557

# %%
#Removing outliers by IQR

#1st Quantile:
Q1= out_features.quantile(0.25)

#3rd Quantile:
Q3=out_features.quantile(0.75)

IQR=Q3-Q1

df2=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %%
df2
# Out:
#           Country                           Region  Happiness Rank  \
# 1         Iceland                   Western Europe               2
# 4          Canada                    North America               5
# 6     Netherlands                   Western Europe               7
# 9       Australia        Australia and New Zealand              10
# 10         Israel  Middle East and Northern Africa              11
# ..            ...                              ...             ...
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 154         Benin               Sub-Saharan Africa             155
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 1              7.561         0.04884                   1.30232  1.40223
# ...

# %%
print("Old Dataframe",df.shape)
print("New Dataframe",df2.shape)
# Out:
# Old Dataframe (158, 12)
# New Dataframe (126, 12)

# %%
#Data loss %

print("Data loss %=",((df.shape[0]-df2.shape[0])/df.shape[0])*100)
# Out:
# Data loss %= 20.253164556962027

# %%
#We will go with Z score because the data loss is less in that case

# %%
df=df1

# %%
#Checking Skewness

df.skew()
# Out:
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
# Here we can see skewness in 'Standard Error','trust' and'generosity

# %%
#Removing Skewness by  square root method:

df['Standard Error']=np.sqrt(df['Standard Error'])
df['Trust (Government Corruption)']=np.sqrt(df['Trust (Government Corruption)'])
df['Generosity']=np.sqrt(df['Generosity'])

# %%
df.skew()
# Out:
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   0.717347
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    0.437253
# Generosity                      -0.285799
# Dystopia Residual               -0.021144
# dtype: float64

# %%
plt.figure(figsize=(22,20))
plotnumber=1
for i in numerical_col:
    if plotnumber<=15:
        plt.subplot(5,3,plotnumber)
        sns.distplot(df[i],color='b')
        plt.xlabel(i)
        plt.yticks(rotation=0)
    plotnumber+=1
plt.tight_layout()

# %%
#We can see the data is almost normally distributed in all after removing skewness

# %%
#Encoding categorical columns

from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      129.0     9.0               1            7.587        0.184689
# 1       57.0     9.0               2            7.561        0.220998
# 2       36.0     9.0               3            7.527        0.182428
# 3      101.0     9.0               4            7.522        0.196977
# 4       24.0     5.0               5            7.427        0.188494
# ..       ...     ...             ...              ...             ...
# 150     65.0     8.0             151            3.655        0.226738
# 151     20.0     8.0             152            3.587        0.207942
# 152      0.0     7.0             153            3.575        0.175613
# 154     13.0     8.0             155            3.340        0.191207
# 156     21.0     8.0             157            2.905        0.294245
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 0 to 156
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        149 non-null    float64
#  1   Region                         149 non-null    float64
#  2   Happiness Rank                 149 non-null    int64
#  3   Happiness Score                149 non-null    float64
#  4   Standard Error                 149 non-null    float64
#  5   Economy (GDP per Capita)       149 non-null    float64
#  6   Family                         149 non-null    float64
#  7   Health (Life Expectancy)       149 non-null    float64
#  8   Freedom                        149 non-null    float64
#  9   Trust (Government Corruption)  149 non-null    float64
#  10  Generosity                     149 non-null    float64
#  11  Dystopia Residual              149 non-null    float64
# ...

# %%
#No object dtypes

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  149.000000  149.000000      149.000000       149.000000
# mean    74.000000    5.080537       77.617450         5.429611
# std     43.156691    3.032519       44.854208         1.111256
# min      0.000000    0.000000        1.000000         2.905000
# 25%     37.000000    3.000000       39.000000         4.610000
# 50%     74.000000    4.000000       78.000000         5.268000
# 75%    111.000000    8.000000      115.000000         6.295000
# max    148.000000    9.000000      157.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      149.000000                149.000000  149.000000
# mean         0.212781                  0.862163    1.008623
# std          0.031180                  0.387975    0.251890
# min          0.135941                  0.000000    0.302850
# 25%          0.191833                  0.593250    0.885880
# ...

# %%
#We can see little to no skewness as mean=median in almost all the columns

# %%
#Checking Correlation

df.corr()
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.009603       -0.125591
# Region                         0.009603  1.000000        0.184520
# Happiness Rank                -0.125591  0.184520        1.000000
# Happiness Score                0.120329 -0.145850       -0.992921
# Standard Error                -0.000357 -0.039047        0.218151
# Economy (GDP per Capita)       0.039897 -0.224928       -0.773651
# Family                         0.202092 -0.127749       -0.720359
# Health (Life Expectancy)       0.037660 -0.334531       -0.736758
# Freedom                        0.091689  0.101335       -0.571089
# Trust (Government Corruption)  0.044601  0.202791       -0.397311
# Generosity                     0.102172  0.307074       -0.199823
# Dystopia Residual              0.048377 -0.059494       -0.526680
#
#                                Happiness Score  Standard Error  \
# ...

# %%
#Visualizing it on heatmap

plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),annot=True,fmt='0.2f',linewidth=1,linecolor='black',cmap='Blues_r')
plt.xlabel("Figure")
plt.ylabel("Features")
plt.title("Descriptive graph")
plt.show()

# %% [markdown]
# #Target variable (Happiness Score) has high positive correlation with 'Health','Family' and 'Economy' and is in highly negative correlation with 'Happiness Rank'

# %%
#Checking the correlation of only target variable

df.corr()['Happiness Score'].sort_values(ascending=False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.773577
# Health (Life Expectancy)         0.729191
# Family                           0.720868
# Freedom                          0.585066
# Dystopia Residual                0.528334
# Trust (Government Corruption)    0.427308
# Generosity                       0.223529
# Country                          0.120329
# Region                          -0.145850
# Standard Error                  -0.236068
# Happiness Rank                  -0.992921
# Name: Happiness Score, dtype: float64

# %%
#Visualising the correlation between the target and the features using the bar map

plt.figure(figsize=(20,22))
df.corr()['Happiness Score'].sort_values(ascending=False).drop(['Happiness Score']).plot(kind='bar',color='r')
plt.title("Correlation between the target and the feature variables using the bar map")
plt.xlabel("Features")
plt.ylabel("Target variable")
plt.show()

# %%
#Seperating Features and Target Variable

x=df.drop(['Happiness Score'],axis=1)
y=df['Happiness Score']

# %%
print("Feature dimensions:",x.shape)
print("Target dimensions:",y.shape)
# Out:
# Feature dimensions: (149, 11)
# Target dimensions: (149,)

# %%
#Feature Scaling using Standard Scalarization


from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#       Country    Region  Happiness Rank  Standard Error  \
# 0    1.278724  1.296837       -1.713905       -0.903989
# 1   -0.395242  1.296837       -1.691535        0.264414
# 2   -0.883482  1.296837       -1.669166       -0.976742
# 3    0.627737  1.296837       -1.646796       -0.508559
# 4   -1.162476 -0.026647       -1.624427       -0.781542
# ..        ...       ...             ...             ...
# 144 -0.209246  0.965966        1.641542        0.449125
# 145 -1.255474  0.965966        1.663911       -0.155705
# 146 -1.720465  0.635095        1.686281       -1.196042
# 147 -1.418221  0.965966        1.731020       -0.694250
# 148 -1.232225  0.965966        1.775759        2.621475
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.381916  1.357879                  1.235390  1.583704
# 1                    1.138324  1.567882                  1.261541  1.338953
# ...

# %%
#Checking Variance Inflation Factor

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#     VIF values                       Features
# 0     1.067909                        Country
# 1     1.472397                         Region
# 2    83.664185                 Happiness Rank
# 3     1.200555                 Standard Error
# 4    14.119395       Economy (GDP per Capita)
# 5     6.419576                         Family
# 6     9.040512       Health (Life Expectancy)
# 7     3.545750                        Freedom
# 8     1.908361  Trust (Government Corruption)
# 9     2.239541                     Generosity
# 10   19.270233              Dystopia Residual

# %%
#Dropping column with the highest VIF

x.drop(['Happiness Rank'],axis=1,inplace=True)

# %%
#Again checking Vif
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#    VIF values                       Features
# 0    1.062073                        Country
# 1    1.418420                         Region
# 2    1.188035                 Standard Error
# 3    4.274273       Economy (GDP per Capita)
# 4    2.034305                         Family
# 5    3.935936       Health (Life Expectancy)
# 6    1.955589                        Freedom
# 7    1.461863  Trust (Government Corruption)
# 8    1.477701                     Generosity
# 9    1.039170              Dystopia Residual

# %% [markdown]
# #### Modelling

# %%
#Import necessary liabraries

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
#Creating Train Test split
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum R2 score is:",maxAccu,"on random state",maxRS)
# Out:
# Maximum R2 score is: 0.999536964852909 on random state 166

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
#Importing all the regression models

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_LR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score: 0.999536964852909
# R2 score on training data: 99.80956629304059
# Mean Absolute Error: 0.02137857100006285
# Mean Squared Error: 0.0007895128635745053
# Root Mean Squared Error 0.028098271540692773

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR,y=y_test,color='r')
plt.plot(pred_LR,pred_LR,color='b')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Linear Regression")
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_RFR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_RFR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2 score: 0.8811081818193753
# R2 score on training data: 98.36173963886154
# Mean Absolute Error: 0.3582284444444454
# Mean Squared Error: 0.20272029114222256
# Root Mean Squared Error 0.4502447014038284

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_RFR,y=y_test,color='r')
plt.plot(pred_RFR,pred_RFR,color='b')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Random Forest Regressor")
plt.show()

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print("R2 score:",r2_score(y_test,pred_knn))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error:",mean_squared_error(y_test,pred_knn))
print("Root Mean Squared Error",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2 score: 0.872600552609077
# R2 score on training data: 89.5412241196463
# Mean Absolute Error: 0.37753777777777786
# Mean Squared Error: 0.21722649599999996
# Root Mean Squared Error 0.4660756333472068

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_knn,y=y_test,color='r')
plt.plot(pred_knn,pred_knn,color='b')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("KNeighbors Regressor")
plt.show()

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_GBR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_GBR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error",np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2 score: 0.9252850345577033
# R2 score on training data: 99.96499201577109
# Mean Absolute Error: 0.2660030615925444
# Mean Squared Error: 0.12739513768838823
# Root Mean Squared Error 0.356924554616782

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_GBR,y=y_test,color='r')
plt.plot(pred_GBR,pred_GBR,color='b')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Gradient Boosting Regressor")
plt.show()

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print("R2 score:",r2_score(y_test,pred_lasso))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error:",mean_squared_error(y_test,pred_lasso))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2 score: -0.001184425279020962
# R2 score on training data: 0.0
# Mean Absolute Error: 1.1351119658119657
# Mean Squared Error: 1.7071014749835633
# Root Mean Squared Error: 1.3065609342788278

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_lasso,y=y_test,color='r')
plt.plot(pred_lasso,pred_lasso,color='b')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Lasso")
plt.show()

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print("R2 score:",r2_score(y_test,pred_rd))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_rd))
print("Mean Squared Error:",mean_squared_error(y_test,pred_rd))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2 score: 0.9994814035510271
# R2 score on training data: 99.80459820557498
# Mean Absolute Error: 0.022174890271540647
# Mean Squared Error: 0.0008842494355783892
# Root Mean Squared Error: 0.02973633191196233

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_rd,y=y_test,color='r')
plt.plot(pred_rd,pred_rd,color='b')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Ridge")
plt.show()

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_train=dtr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_dtr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_dtr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_dtr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2 score: 0.8139145531822376
# R2 score on training data: 100.0
# Mean Absolute Error: 0.4621333333333334
# Mean Squared Error: 0.3172909333333334
# Root Mean Squared Error: 0.563285836261958

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_dtr,y=y_test,color='r')
plt.plot(pred_dtr,pred_dtr,color='b')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Decision Tree Regressor")
plt.show()

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_svr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_svr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_svr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# R2 score: 0.9050733703809071
# R2 score on training data: 99.08628346446365
# Mean Absolute Error: 0.24564452533261602
# Mean Squared Error: 0.16185768110886284
# Root Mean Squared Error: 0.4023154000394005

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_svr,y=y_test,color='r')
plt.plot(pred_svr,pred_svr,color='b')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("SVR")
plt.show()

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_etr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_etr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_etr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# R2 score: 0.9109793356104448
# R2 score on training data: 100.0
# Mean Absolute Error: 0.2906513333333338
# Mean Squared Error: 0.15178752649999983
# Root Mean Squared Error: 0.3895991869858045

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_etr,y=y_test,color='r')
plt.plot(pred_etr,pred_etr,color='b')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Extra Trees Regressor")
plt.show()

# %%
#Calculating Cross Value Score for every model

from sklearn.model_selection import cross_val_score
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference between R2 and CV is:",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.96410649 0.97246661 0.93798426 0.87817787 0.99329354]
# 0.9492057531643392
# Difference between R2 and CV is: 5.0331211688569795

# %%
score=cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print("Difference between R2 and CV is:",(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [-8.52208542 -0.96218193 -1.11882167 -1.65168487 -6.49412235]
# -3.749779246720994
# Difference between R2 and CV is: 463.0887428540369

# %%
score=cross_val_score(knn,x,y)
print(score)
print(score.mean())
print("Difference between R2 and CV is:",(r2_score(y_test,pred_knn)-score.mean())*100)
# Out:
# [-9.91119432 -2.03869525 -2.22458977 -8.61379574 -5.70902851]
# -5.699460718151068
# Difference between R2 and CV is: 657.2061270760145

# %%
score=cross_val_score(GBR,x,y)
print(score)
print(score.mean())
print("Difference between R2 and CV is:",(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [-4.81069067 -0.19751445 -1.1058154  -2.59281562 -4.46215075]
# -2.633797379113033
# Difference between R2 and CV is: 355.9082413670736

# %%
score=cross_val_score(lasso,x,y)
print(score)
print(score.mean())
print("Difference between R2 and CV is:",(r2_score(y_test,pred_lasso)-score.mean())*100)
# Out:
# [-42.37117014 -11.06215836  -0.30321946 -32.72956581 -29.0315447 ]
# -23.099531692553747
# Difference between R2 and CV is: 2309.8347267274726

# %%
score=cross_val_score(rd,x,y)
print(score)
print(score.mean())
print("Difference between R2 and CV is:",(r2_score(y_test,pred_rd)-score.mean())*100)
# Out:
# [0.94251602 0.97263353 0.93872229 0.87592422 0.99058896]
# 0.9440770015353539
# Difference between R2 and CV is: 5.54044020156732

# %%
score=cross_val_score(dtr,x,y)
print(score)
print(score.mean())
print("Difference between R2 and CV is:",(r2_score(y_test,pred_dtr)-score.mean())*100)
# Out:
# [ -8.85133863 -11.29128266  -7.65897115 -11.78546643  -5.97352131]
# -9.112116036830368
# Difference between R2 and CV is: 992.6030590012607

# %%
score=cross_val_score(svr,x,y)
print(score)
print(score.mean())
print("Difference between R2 and CV is:",(r2_score(y_test,pred_svr)-score.mean())*100)
# Out:
# [-10.75973459   0.13652347   0.80340053  -1.05657982  -5.73372507]
# -3.3220230978672967
# Difference between R2 and CV is: 422.7096468248204

# %%
score=cross_val_score(etr,x,y)
print(score)
print(score.mean())
print("Difference between R2 and CV is:",(r2_score(y_test,pred_etr)-score.mean())*100)
# Out:
# [-7.98952749 -0.10752752 -1.31619152 -1.62963927 -5.78667282]
# -3.3659117219198635
# Difference between R2 and CV is: 427.68910575303084

# %% [markdown]
# #In the models where the difference is coming high it means there is over fitting problem. Which means that the model is performing well on the training data but not very well on the unseen data.

# %%
#From the difference we conclude Linear regression is the best performing model

# %% [markdown]
# #### Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'fit_intercept':[True,False],
      'copy_X':[True,False],
      'n_jobs':[-2,-1,1],
      'positive':[True,False]}

# %%
gscv=GridSearchCV(LinearRegression(),param,cv=5)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False], 'n_jobs': [-2, -1, 1],
#                          'positive': [True, False]})

# %%
gscv.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': -2, 'positive': True}

# %%
Model=LinearRegression(copy_X= True, fit_intercept=True, n_jobs= -2, positive= True)

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print("R2 score:",r2_score(y_test,pred))
print("Mean Absolute Error:",mean_absolute_error(y_test,pred))
print("Mean Squared Error:",mean_squared_error(y_test,pred))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 score: 0.9995113529864197
# Mean Absolute Error: 0.022489314368538002
# Mean Squared Error: 0.0008331831943917476
# Root Mean Squared Error: 0.028864912859590405

# %%
#Saving the model

import pickle
filename='World Happiness Report Project.pkl'
pickle.dump(Model,open(filename, 'wb'))  #saved model

# %%
#loading the model

loaded_model=pickle.load(open('World Happiness Report Project.pkl','rb'))  #read binary mode
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 99.95113529864197

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","original"])   
conclusion
# Out:
#                  0         1         2         3         4         5   \
# Predicted  3.797565  5.116842  4.259179  2.917072  6.290595  6.504266
# original   3.819000  5.140000  4.292000  2.905000  6.269000  6.485000
#
#                  6         7         8         9   ...        35       36  \
# Predicted  4.734512  5.539677  6.873701  5.732574  ...  5.614751  5.28178
# original   4.739000  5.548000  6.901000  5.689000  ...  5.605000  5.28600
#
#                  37        38        39        40        41        42  \
# Predicted  6.937147  4.515676  4.738372  4.221619  5.991987  3.338809
# original   6.946000  4.514000  4.677000  4.194000  5.948000  3.340000
#
#                  43        44
# Predicted  5.000853  5.900087
# original   5.013000  5.890000
#
# [2 rows x 45 columns]
