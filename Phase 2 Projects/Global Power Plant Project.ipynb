# %%
#Import necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Importing Dataset

# %%
df=pd.read_excel("power plant dataset1.xlsx")
df
# Out:
#     Unnamed: 0    Unnamed: 1 Unnamed: 2                    Unnamed: 3  \
# 0      country  country_long       name                     gppd_idnr
# 1          690           IND      India          SANGLI MIRAJ BIOMASS
# 2          691           IND      India             SANGLI VASANTDADA
# 3          692           IND      India                  SANJAY BHABA
# 4          693           IND      India                 SANJAY GANDHI
# ..         ...           ...        ...                           ...
# 215        904           IND      India                  YERMARUS TPP
# 216        905           IND      India  Yelesandra Solar Power Plant
# 217        906           IND      India  Yelisirur wind power project
# 218        907           IND      India                   ZAWAR MINES
# 219        908           IND      India       iEnergy Theni Wind Farm
#
#       Unnamed: 4 Unnamed: 5 Unnamed: 6    Unnamed: 7   Unnamed: 8  \
# ...

# %%
# Set the first row as column names

df.columns = df.iloc[0]
df = df[1:]  # Remove the first row

# %%
df
# Out:
# 0   country country_long   name                     gppd_idnr capacity_mw  \
# 1       690          IND  India          SANGLI MIRAJ BIOMASS  WRI1019982
# 2       691          IND  India             SANGLI VASANTDADA  WRI1019983
# 3       692          IND  India                  SANJAY BHABA  IND0000391
# 4       693          IND  India                 SANJAY GANDHI  IND0000392
# 5       694          IND  India               SANKESHWAR MILL  WRI1019933
# ..      ...          ...    ...                           ...         ...
# 215     904          IND  India                  YERMARUS TPP  IND0000513
# 216     905          IND  India  Yelesandra Solar Power Plant  WRI1026222
# 217     906          IND  India  Yelisirur wind power project  WRI1026776
# 218     907          IND  India                   ZAWAR MINES  WRI1019901
# 219     908          IND  India       iEnergy Theni Wind Farm  WRI1026761
#
# 0   latitude longitude primary_fuel other_fuel1 other_fuel2  ...  \
# ...

# %%
df.head()
# Out:
# 0 country country_long   name             gppd_idnr capacity_mw latitude  \
# 1     690          IND  India  SANGLI MIRAJ BIOMASS  WRI1019982       10
# 2     691          IND  India     SANGLI VASANTDADA  WRI1019983     12.5
# 3     692          IND  India          SANJAY BHABA  IND0000391      120
# 4     693          IND  India         SANJAY GANDHI  IND0000392     1340
# 5     694          IND  India       SANKESHWAR MILL  WRI1019933       26
#
# 0 longitude primary_fuel other_fuel1 other_fuel2  ... year_of_capacity_data  \
# 1   16.9171      74.4821     Biomass         NaN  ...                   NaN
# 2    16.881      74.5898     Biomass         NaN  ...                   NaN
# 3   31.2642      78.4835       Hydro         NaN  ...                   NaN
# 4   23.3026      81.0668        Coal         Oil  ...                   NaN
# 5   16.2478      74.5003     Biomass         NaN  ...                   NaN
#
# 0 generation_gwh_2013 generation_gwh_2014 generation_gwh_2015  \
# ...

# %%
df.tail()
# Out:
# 0   country country_long   name                     gppd_idnr capacity_mw  \
# 215     904          IND  India                  YERMARUS TPP  IND0000513
# 216     905          IND  India  Yelesandra Solar Power Plant  WRI1026222
# 217     906          IND  India  Yelisirur wind power project  WRI1026776
# 218     907          IND  India                   ZAWAR MINES  WRI1019901
# 219     908          IND  India       iEnergy Theni Wind Farm  WRI1026761
#
# 0   latitude longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 215     1600   16.2949      77.3568        Coal         Oil  ...
# 216        3   12.8932      78.1654       Solar         NaN  ...
# 217     25.5   15.2758      75.5811        Wind         NaN  ...
# 218       80     24.35      73.7477        Coal         NaN  ...
# 219     16.5    9.9344      77.4768        Wind         NaN  ...
#
# 0   year_of_capacity_data generation_gwh_2013 generation_gwh_2014  \
# ...

# %% [markdown]
# #Exploratory Data Analysis(EDA)

# %%
df.shape   #checking the dimension of data
# Out:
# (219, 27)

# %%
df.columns.tolist()   #All the columns in a list
# Out:
# ['country',
#  'country_long',
#  'name',
#  'gppd_idnr',
#  'capacity_mw',
#  'latitude',
#  'longitude',
#  'primary_fuel',
#  'other_fuel1',
#  'other_fuel2',
#  'other_fuel3',
#  'commissioning_year',
#  'owner',
#  'source',
#  'url',
#  'geolocation_source',
#  'wepp_id',
#  'year_of_capacity_data',
#  'generation_gwh_2013',
#  'generation_gwh_2014',
#  'generation_gwh_2015',
#  'generation_gwh_2016',
#  'generation_gwh_2017',
#  'generation_gwh_2018',
#  'generation_gwh_2019',
#  'generation_data_source',
#  'estimated_generation_gwh']

# %%
df.dtypes   #datatype of all the columns
# Out:
# 0
# country                     object
# country_long                object
# name                        object
# gppd_idnr                   object
# capacity_mw                 object
# latitude                    object
# longitude                   object
# primary_fuel                object
# other_fuel1                 object
# other_fuel2                 object
# other_fuel3                 object
# commissioning_year          object
# owner                       object
# source                      object
# url                         object
# geolocation_source          object
# wepp_id                     object
# year_of_capacity_data       object
# generation_gwh_2013         object
# generation_gwh_2014         object
# generation_gwh_2015         object
# generation_gwh_2016         object
# generation_gwh_2017         object
# generation_gwh_2018         object
# generation_gwh_2019         object
# generation_data_source      object
# ...

# %% [markdown]
# #We can see that all the columns are of object dtype but there are columns like primary fuel,latitude,longitude that has float data....so something is wrong

# %%
df.isnull().sum()   #sum of all the null values in each columns
# Out:
# 0
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                      0
# longitude                    15
# primary_fuel                 15
# other_fuel1                   0
# other_fuel2                 165
# other_fuel3                 218
# commissioning_year          219
# owner                        91
# source                      139
# url                           1
# geolocation_source            1
# wepp_id                       9
# year_of_capacity_data       219
# generation_gwh_2013          91
# generation_gwh_2014         219
# generation_gwh_2015         129
# generation_gwh_2016         121
# generation_gwh_2017         118
# generation_gwh_2018         117
# generation_gwh_2019         115
# generation_data_source      219
# estimated_generation_gwh    114
# dtype: int64

# %% [markdown]
# #We can see there are significant number of null values in other_fuel2,other_fuel3,commissioning_year,owner,source,year_of_capacity_data,generation_gwh_2013,generation_gwh_2014,generation_gwh_2015,generation_gwh_2016,generation_gwh_2017,generation_gwh_2018,generation_gwh_2019,estimated_generation_gwh

# %%
df.nunique()
# Out:
# 0
# country                     219
# country_long                  1
# name                          1
# gppd_idnr                   219
# capacity_mw                 219
# latitude                    142
# longitude                   198
# primary_fuel                198
# other_fuel1                   8
# other_fuel2                   3
# other_fuel3                   1
# commissioning_year            0
# owner                        53
# source                       65
# url                          46
# geolocation_source           73
# wepp_id                       2
# year_of_capacity_data         0
# generation_gwh_2013           1
# generation_gwh_2014           0
# generation_gwh_2015          85
# generation_gwh_2016          94
# generation_gwh_2017          95
# generation_gwh_2018          96
# generation_gwh_2019          96
# generation_data_source        0
# estimated_generation_gwh      1
# dtype: int64

# %%
#checking the value counts of unique values in each column

for i in df.columns:
    print(df[i].value_counts())
    print('\n')  #new line
# Out:
# 690    1
# 840    1
# 829    1
# 830    1
# 831    1
#       ..
# 766    1
# 767    1
# 768    1
# 769    1
# 908    1
# Name: country, Length: 219, dtype: int64
#
#
# IND    219
# Name: country_long, dtype: int64
#
#
# India    219
# Name: name, dtype: int64
#
#
# SANGLI MIRAJ BIOMASS                            1
# Torrent Gujurat Wind Farm                       1
# Talcher Kaniha Solar Power Plant                1
# Tamilnadu Wind Farm                             1
# Tata BP - Electronics City Solar Panel Plant    1
#                                                ..
# Shree Nashik Wind Farm                          1
# Shree Sangli Wind Farm                          1
# Shree Southern Wind Farm                        1
# Shri Singaji MALWA TPP                          1
# iEnergy Theni Wind Farm                         1
# Name: gppd_idnr, Length: 219, dtype: int64
#
#
# WRI1019982    1
# WRI1026765    1
# WRI1026215    1
# WRI1026102    1
# WRI1026216    1
#              ..
# ...

# %%
#Dropping all these columns as most of the values in them are null

df.drop("other_fuel2",axis=1,inplace=True)
df.drop("other_fuel3",axis=1,inplace=True)
df.drop("commissioning_year",axis=1,inplace=True)
df.drop("owner",axis=1,inplace=True)
df.drop("source",axis=1,inplace=True)
df.drop("year_of_capacity_data",axis=1,inplace=True)
df.drop("generation_gwh_2013",axis=1,inplace=True)
df.drop("generation_gwh_2014",axis=1,inplace=True)
df.drop("generation_gwh_2015",axis=1,inplace=True)
df.drop("generation_gwh_2016",axis=1,inplace=True)
df.drop("generation_gwh_2017",axis=1,inplace=True)
df.drop("generation_gwh_2018",axis=1,inplace=True)
df.drop("generation_gwh_2019",axis=1,inplace=True)
df.drop("generation_data_source",axis=1,inplace=True)
df.drop("estimated_generation_gwh",axis=1,inplace=True)

# %%
#Checking the null values again

df.isnull().sum()
# Out:
# 0
# country                0
# country_long           0
# name                   0
# gppd_idnr              0
# capacity_mw            0
# latitude               0
# longitude             15
# primary_fuel          15
# other_fuel1            0
# url                    1
# geolocation_source     1
# wepp_id                9
# dtype: int64

# %%
df['country']=df['country'].astype(float)  #changing the dtype from object to float
df['latitude']=df['latitude'].astype(float)  #changing the dtype from object to float
df['longitude']=df['longitude'].astype(float)  #changing the dtype from object to float
df['primary_fuel']=df['primary_fuel'].astype(float)  #changing the dtype from object to float

# %%
#Checking dtype again

df.dtypes
# Out:
# 0
# country               float64
# country_long           object
# name                   object
# gppd_idnr              object
# capacity_mw            object
# latitude              float64
# longitude             float64
# primary_fuel          float64
# other_fuel1            object
# url                    object
# geolocation_source     object
# wepp_id                object
# dtype: object

# %%
#Filling the null values of rest of the columns by their mean and mode values

df['longitude']=df['longitude'].fillna(df['longitude'].mean())
df['primary_fuel']=df['primary_fuel'].fillna(df['primary_fuel'].mean())
df['url']=df['url'].fillna(df['url'].mode()[0])
df['geolocation_source']=df['geolocation_source'].fillna(df['geolocation_source'].mode()[0])
df['wepp_id']=df['wepp_id'].fillna(df['wepp_id'].mode()[0])

# %% [markdown]
# #Dropping column nam ebecause the name or title of the power plant may not provide valuable information for predicting the primary fuel or capacity.

# %%
df.drop("name",axis=1,inplace=True)

# %% [markdown]
# #Dropping other_fuel1 because this column represent additional energy sources used in electricity generation or export. If you are predicting the primary fuel, this column can be dropped since you are focused on the main fuel source.

# %%
df.drop("other_fuel1",axis=1,inplace=True)

# %% [markdown]
# #Dropping url column because column contain information about the source of the data and web document references. They may not be relevant for predicting the primary fuel or capacity.

# %%
df.drop("url",axis=1,inplace=True)

# %% [markdown]
# #Dropping geolocation_source because this column provides attribution for geolocation information and may not directly impact the prediction task.

# %%
df.drop("geolocation_source",axis=1,inplace=True)

# %%
#now check the null values

df.isnull().sum()
# Out:
# 0
# country         0
# country_long    0
# gppd_idnr       0
# capacity_mw     0
# latitude        0
# longitude       0
# primary_fuel    0
# wepp_id         0
# dtype: int64

# %%
#Visualizing in a heatmap

sns.heatmap(df.isnull(),cmap="cool_r")
# Out:
# <AxesSubplot:xlabel='0'>

# %%
#Heatmap is of same colour entirely because there are no null values

# %%
df
# Out:
# 0    country country_long                     gppd_idnr capacity_mw  latitude  \
# 1      690.0          IND          SANGLI MIRAJ BIOMASS  WRI1019982      10.0
# 2      691.0          IND             SANGLI VASANTDADA  WRI1019983      12.5
# 3      692.0          IND                  SANJAY BHABA  IND0000391     120.0
# 4      693.0          IND                 SANJAY GANDHI  IND0000392    1340.0
# 5      694.0          IND               SANKESHWAR MILL  WRI1019933      26.0
# ..       ...          ...                           ...         ...       ...
# 215    904.0          IND                  YERMARUS TPP  IND0000513    1600.0
# 216    905.0          IND  Yelesandra Solar Power Plant  WRI1026222       3.0
# 217    906.0          IND  Yelisirur wind power project  WRI1026776      25.5
# 218    907.0          IND                   ZAWAR MINES  WRI1019901      80.0
# 219    908.0          IND       iEnergy Theni Wind Farm  WRI1026761      16.5
#
# ...

# %%
print("Total duplicate rows are:",df.duplicated().sum())   #This function is used to check the duplicate rows in the df
# Out:
# Total duplicate rows are: 0

# %%
#checking number of unique values in each column

df.nunique()
# Out:
# 0
# country         219
# country_long      1
# gppd_idnr       219
# capacity_mw     219
# latitude        142
# longitude       199
# primary_fuel    199
# wepp_id           2
# dtype: int64

# %%
df.nunique().to_frame("Number of unique values")
# Out:
#               Number of unique values
# 0
# country                           219
# country_long                        1
# gppd_idnr                         219
# capacity_mw                       219
# latitude                          142
# longitude                         199
# primary_fuel                      199
# wepp_id                             2

# %% [markdown]
# ### Encoding Categorical columns

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1)) 
        
df
# Out:
# 0    country  country_long  gppd_idnr  capacity_mw  latitude  longitude  \
# 1      690.0           0.0        0.0        136.0      10.0    16.9171
# 2      691.0           0.0        1.0        137.0      12.5    16.8810
# 3      692.0           0.0        2.0          0.0     120.0    31.2642
# 4      693.0           0.0        3.0          1.0    1340.0    23.3026
# 5      694.0           0.0        4.0        131.0      26.0    16.2478
# ..       ...           ...        ...          ...       ...        ...
# 215    904.0           0.0      214.0        120.0    1600.0    16.2949
# 216    905.0           0.0      215.0        186.0       3.0    12.8932
# 217    906.0           0.0      216.0        213.0      25.5    15.2758
# 218    907.0           0.0      217.0        130.0      80.0    24.3500
# 219    908.0           0.0      218.0        202.0      16.5     9.9344
#
# 0    primary_fuel  wepp_id
# 1         74.4821      1.0
# 2         74.5898      1.0
# ...

# %%
df.describe()   #Statistical description
# Out:
# 0         country  country_long   gppd_idnr  capacity_mw     latitude  \
# count  219.000000         219.0  219.000000   219.000000   219.000000
# mean   799.000000           0.0  109.000000   109.000000   370.803292
# std     63.364028           0.0   63.364028    63.364028   702.114749
# min    690.000000           0.0    0.000000     0.000000     0.000000
# 25%    744.500000           0.0   54.500000    54.500000    15.000000
# 50%    799.000000           0.0  109.000000   109.000000    52.800000
# 75%    853.500000           0.0  163.500000   163.500000   421.000000
# max    908.000000           0.0  218.000000   218.000000  4760.000000
#
# 0       longitude  primary_fuel     wepp_id
# count  219.000000    219.000000  219.000000
# mean    19.856578     77.670230    0.894977
# std      6.079144      4.474701    0.307285
# min      8.689500     69.827600    0.000000
# 25%     16.170350     74.491200    1.000000
# 50%     19.856578     77.330000    1.000000
# ...

# %%
#if mean>median its right skewed i.e. in latitude
#max value is very high than the 75% data i.e. outliers are present

# %%
#Visualization on heat map

plt.figure(figsize=(22,10))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linewidth=1,linecolor='black',cmap='Spectral')
plt.xlabel('Figure',fontsize=14)
plt.ylabel("Features_name",fontsize=14)
plt.title("Descriptive Graph",fontsize=20)
plt.show()

# %% [markdown]
# ### Univariate analysis

# %%
datamap=sns.countplot(df["country_long"],data=df)
print(df["country_long"].value_counts())
# Out:
# 0.0    219
# Name: country_long, dtype: int64

# %%
#Here we can see that the column country_long has only one unique value i.e India. It is showing all the data only for India

# %%
datamap=sns.countplot(df["wepp_id"],data=df)
print(df["wepp_id"].value_counts())
# Out:
# 1.0    196
# 0.0     23
# Name: wepp_id, dtype: int64

# %%
#here we can see that there are 2 wepp_id in which WRI has 196 datas and Industry about only 23

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.lmplot(x='latitude',y='primary_fuel',data=df)

# %%
#Here we can see that latitude has positive correlation with primary_fuel

# %%
sns.lmplot(x='longitude',y='primary_fuel',data=df)

# %%
#Longitude has a little positive correlation with primary_fuel

# %%
sns.lmplot(x='latitude',y='capacity_mw',data=df)

# %%
#Here we can see that latitude has a negative correlation with capacity

# %%
sns.lmplot(x='longitude',y='capacity_mw',data=df)

# %%
#Longitude is also negatively correlated with Capacity and the data is very much scattered

# %%
sns.lmplot(x='primary_fuel',y='capacity_mw',data=df)

# %%
#Primary fuel is negatively correlated to capacity

# %%
sns.lmplot(x='country',y='gppd_idnr',data=df)

# %%
#here we can see that country and gppd_idnr are highly positively correlated with each other in linear correlation

# %%
plt.figure(figsize=(20,15))
p=1
for i in df.columns:
    if p<=20:    
        plt.subplot(5,4,p) 
        sns.regplot(x='primary_fuel',y=i,data=df,color='r')
        plt.xlabel("primary_fuel")
        plt.ylabel(i)
    p+=1
plt.show()

# %%
plt.figure(figsize=(20,15))
p=1
for i in df.columns:
    if p<=20:    
        plt.subplot(5,4,p) 
        sns.scatterplot(x='primary_fuel',y=i,data=df,color='r')
        plt.xlabel("primary_fuel")
        plt.ylabel(i)
    p+=1
plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(data=df,palette='Dark2')

# %%
#Let's check the outliers by plotting the boxplot

plt.figure(figsize=(25,25))
p=1
for i in df.columns:
    if p<=25:
        plt.subplot(5,5,p)
        sns.boxplot(df[i],palette="Set2_r")
        plt.xlabel(i)
    p+=1
plt.show()

# %%
#Here we can see outliers in latitude,primary_fuel and wepp_id

# %% [markdown]
# #We will not remove outliers from primary_fuel as its the target variable and also not from wepp_id because it is a categorical column

# %%
#Removing outliers from wepp_id by z score


from scipy.stats import zscore
out_features=df[['wepp_id']]
z=np.abs(zscore(out_features))  #This applies the abs() function to each element of the z-score array to obtain the absolute values of the z-scores and it will make any negative value to positive if coming. 
z
# Out:
# 0     wepp_id
# 1    0.342559
# 2    0.342559
# 3    0.342559
# 4    0.342559
# 5    0.342559
# ..        ...
# 215  0.342559
# 216  2.919202
# 217  0.342559
# 218  0.342559
# 219  0.342559
#
# [219 rows x 1 columns]

# %%
#threshold=3

np.where(z>3)
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
#Now removing the data above Z score and creating a new df

df1=df[(z<3).all(axis=1)]  
df1
# Out:
# 0    country  country_long  gppd_idnr  capacity_mw  latitude  longitude  \
# 1      690.0           0.0        0.0        136.0      10.0    16.9171
# 2      691.0           0.0        1.0        137.0      12.5    16.8810
# 3      692.0           0.0        2.0          0.0     120.0    31.2642
# 4      693.0           0.0        3.0          1.0    1340.0    23.3026
# 5      694.0           0.0        4.0        131.0      26.0    16.2478
# ..       ...           ...        ...          ...       ...        ...
# 215    904.0           0.0      214.0        120.0    1600.0    16.2949
# 216    905.0           0.0      215.0        186.0       3.0    12.8932
# 217    906.0           0.0      216.0        213.0      25.5    15.2758
# 218    907.0           0.0      217.0        130.0      80.0    24.3500
# 219    908.0           0.0      218.0        202.0      16.5     9.9344
#
# 0    primary_fuel  wepp_id
# 1         74.4821      1.0
# 2         74.5898      1.0
# ...

# %%
#Checking the data loss percentage after removing the outliers

print("Data Loss Percentage:", ((df.shape[0]-df1.shape[0])/df.shape[0])*100)    #Change in data/original data *100
# Out:
# Data Loss Percentage: 0.0

# %%
#Now lets check with IQR method:

#1st Quantile
Q1=out_features.quantile(0.25)

#3rd Quantile
Q3=out_features.quantile(0.75)

IQR=Q3-Q1

df2=df[~((df < (Q1-1.5*IQR))|(df> (Q3+ 1.5*IQR))).any(axis=1)]

# %%
df2
# Out:
# 0    country  country_long  gppd_idnr  capacity_mw  latitude  longitude  \
# 1      690.0           0.0        0.0        136.0      10.0    16.9171
# 2      691.0           0.0        1.0        137.0      12.5    16.8810
# 3      692.0           0.0        2.0          0.0     120.0    31.2642
# 4      693.0           0.0        3.0          1.0    1340.0    23.3026
# 5      694.0           0.0        4.0        131.0      26.0    16.2478
# ..       ...           ...        ...          ...       ...        ...
# 214    903.0           0.0      213.0        119.0     106.6    13.1156
# 215    904.0           0.0      214.0        120.0    1600.0    16.2949
# 217    906.0           0.0      216.0        213.0      25.5    15.2758
# 218    907.0           0.0      217.0        130.0      80.0    24.3500
# 219    908.0           0.0      218.0        202.0      16.5     9.9344
#
# 0    primary_fuel  wepp_id
# 1         74.4821      1.0
# 2         74.5898      1.0
# ...

# %%
print("Data Loss Percentage:", ((df.shape[0]-df2.shape[0])/df.shape[0])*100)    #Change in data/original data *100
# Out:
# Data Loss Percentage: 10.50228310502283

# %%
#Z score is not removing any outliers so considering IQR method

# %%
df=df2

# %%
df
# Out:
# 0    country  country_long  gppd_idnr  capacity_mw  latitude  longitude  \
# 1      690.0           0.0        0.0        136.0      10.0    16.9171
# 2      691.0           0.0        1.0        137.0      12.5    16.8810
# 3      692.0           0.0        2.0          0.0     120.0    31.2642
# 4      693.0           0.0        3.0          1.0    1340.0    23.3026
# 5      694.0           0.0        4.0        131.0      26.0    16.2478
# ..       ...           ...        ...          ...       ...        ...
# 214    903.0           0.0      213.0        119.0     106.6    13.1156
# 215    904.0           0.0      214.0        120.0    1600.0    16.2949
# 217    906.0           0.0      216.0        213.0      25.5    15.2758
# 218    907.0           0.0      217.0        130.0      80.0    24.3500
# 219    908.0           0.0      218.0        202.0      16.5     9.9344
#
# 0    primary_fuel  wepp_id
# 1         74.4821      1.0
# 2         74.5898      1.0
# ...

# %%
#Checking skewness


df.skew()
# Out:
# 0
# country        -0.063478
# country_long    0.000000
# gppd_idnr      -0.063478
# capacity_mw     0.232962
# latitude        2.971021
# longitude       0.207503
# primary_fuel    1.050833
# wepp_id         0.000000
# dtype: float64

# %%
#We can see high skewness in latitude and primary_fuel

# %%
#We do not remove skewness from the target variable

# %%
#removing skewness from latitude by log

df['latitude']=np.log(df['latitude'])

# %%
#Checking skewness again

df.skew()
# Out:
# 0
# country        -0.063478
# country_long    0.000000
# gppd_idnr      -0.063478
# capacity_mw     0.232962
# latitude        0.002413
# longitude       0.207503
# primary_fuel    1.050833
# wepp_id         0.000000
# dtype: float64

# %%
#No more skewness

# %%
#Let's visualize again

plt.figure(figsize=(20,25),facecolor='green')
plotnumber=1

for i in df.columns:   
    if plotnumber<=25:
        plt.subplot(6,5,plotnumber)
        sns.distplot(df[i],color='m')
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.show()

# %%
#Now we will check correlation 

df.corr()
# Out:
# 0              country  country_long  gppd_idnr  capacity_mw  latitude  \
# 0
# country       1.000000           NaN   0.999999     0.427231  0.027399
# country_long       NaN           NaN        NaN          NaN       NaN
# gppd_idnr     0.999999           NaN   1.000000     0.427227  0.027318
# capacity_mw   0.427231           NaN   0.427227     1.000000 -0.436740
# latitude      0.027399           NaN   0.027318    -0.436740  1.000000
# longitude    -0.048558           NaN  -0.048567    -0.222048  0.199520
# primary_fuel -0.024165           NaN  -0.024168    -0.279879  0.226089
# wepp_id            NaN           NaN        NaN          NaN       NaN
#
# 0             longitude  primary_fuel  wepp_id
# 0
# country       -0.048558     -0.024165      NaN
# country_long        NaN           NaN      NaN
# gppd_idnr     -0.048567     -0.024168      NaN
# capacity_mw   -0.222048     -0.279879      NaN
# latitude       0.199520      0.226089      NaN
# ...

# %%
#Dropping country_long and wepp_id as it is showing NaN correlation

# %%
df.drop("country_long",axis=1,inplace=True)
df.drop("wepp_id",axis=1,inplace=True)

# %%
df.corr()
# Out:
# 0              country  gppd_idnr  capacity_mw  latitude  longitude  \
# 0
# country       1.000000   0.999999     0.427231  0.027399  -0.048558
# gppd_idnr     0.999999   1.000000     0.427227  0.027318  -0.048567
# capacity_mw   0.427231   0.427227     1.000000 -0.436740  -0.222048
# latitude      0.027399   0.027318    -0.436740  1.000000   0.199520
# longitude    -0.048558  -0.048567    -0.222048  0.199520   1.000000
# primary_fuel -0.024165  -0.024168    -0.279879  0.226089   0.166973
#
# 0             primary_fuel
# 0
# country          -0.024165
# gppd_idnr        -0.024168
# capacity_mw      -0.279879
# latitude          0.226089
# longitude         0.166973
# primary_fuel      1.000000

# %%
#Visualizing it on the heatmap

plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,fmt='0.2f',linewidth=1,linecolor='black')
plt.xlabel("Figure")
plt.ylabel("Features name")
plt.title("Descriptive Graph")
plt.show()

# %%
#Here we can see independent variables having high correlation among each other i.e. the problem of multicolliniarity exists

# %% [markdown]
# ### Taking primary_fuel as target

# %%
#Checking the correlation of target variable only

df.corr()['primary_fuel'].sort_values(ascending=False)
# Out:
# 0
# primary_fuel    1.000000
# latitude        0.226089
# longitude       0.166973
# country        -0.024165
# gppd_idnr      -0.024168
# capacity_mw    -0.279879
# Name: primary_fuel, dtype: float64

# %%
#All the features are very less correlated to the target i.e. they do not contribute too much in its prediction

# %%
#Visualizing the correlation between the features and the label using bar plot

plt.figure(figsize=(22,7))
df.corr()['primary_fuel'].sort_values(ascending=False).drop(['primary_fuel']).plot(kind='bar',color='y')
plt.title("Correlation between features and label using bar plot",fontsize=20)
plt.xlabel("Features")
plt.ylabel("Target variable")
plt.show()

# %% [markdown]
# #### Seperating features and label

# %%
x=df.drop(['primary_fuel'],axis=1)
y=df["primary_fuel"]

# %%
x
# Out:
# 0    country  gppd_idnr  capacity_mw  latitude  longitude
# 1      690.0        0.0        136.0  2.302585    16.9171
# 2      691.0        1.0        137.0  2.525729    16.8810
# 3      692.0        2.0          0.0  4.787492    31.2642
# 4      693.0        3.0          1.0  7.200425    23.3026
# 5      694.0        4.0        131.0  3.258097    16.2478
# ..       ...        ...          ...       ...        ...
# 214    903.0      213.0        119.0  4.669084    13.1156
# 215    904.0      214.0        120.0  7.377759    16.2949
# 217    906.0      216.0        213.0  3.238678    15.2758
# 218    907.0      217.0        130.0  4.382027    24.3500
# 219    908.0      218.0        202.0  2.803360     9.9344
#
# [196 rows x 5 columns]

# %%
print("Feature dimensions:",x.shape)
print("Target dimensions:",y.shape)
# Out:
# Feature dimensions: (196, 5)
# Target dimensions: (196,)

# %% [markdown]
# #### Feature scaling using standard scalarisation

# %%
#To remove the biasness

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
# 0     country  gppd_idnr  capacity_mw  latitude  longitude
# 0   -1.694071  -1.694071     0.557125 -1.096758  -0.459875
# 1   -1.678537  -1.678537     0.573159 -0.983909  -0.465711
# 2   -1.663003  -1.663003    -1.623597  0.159910   1.859432
# 3   -1.647469  -1.647469    -1.607562  1.380179   0.572385
# 4   -1.631935  -1.631935     0.476951 -0.613536  -0.568072
# ..        ...        ...          ...       ...        ...
# 191  1.614657   1.614657     0.284534  0.100028  -1.074413
# 192  1.630191   1.630191     0.300569  1.469860  -0.560458
# 193  1.661259   1.661259     1.791798 -0.623356  -0.725202
# 194  1.676793   1.676793     0.460916 -0.045142   0.741704
# 195  1.692327   1.692327     1.615416 -0.843505  -1.588676
#
# [196 rows x 5 columns]

# %%
#Checking Vif in every scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#       VIF values     Features
# 0  407663.605920      country
# 1  407638.412272    gppd_idnr
# 2       1.659216  capacity_mw
# 3       1.347888     latitude
# 4       1.066989    longitude

# %% [markdown]
# #VIF is very high in country and gppd_idnr. VIF till 5 is fine. But as we only have 5 columns here and if we remove even 1 column we can lose 20% of our data so we cannot remove the whole column here.

# %% [markdown]
# #### Modelling

# %%
#Importing libraries

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Performance Parameters for Regression Models:
#
# 1.Mean Absolute Error (MAE)
#
# 2.Mean Squared Error (MSE)
#
# 3.Root Mean Squared Error (RMSE)
#
# 4.R-squared (R²) score
#
# 5.Mean Absolute Percentage Error (MAPE)

# %% [markdown]
# #### Creating train test split

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum R2 score is:",maxAccu,"on random state",maxRS)
# Out:
# Maximum R2 score is: 0.158822016773438 on random state 142

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
#Importing all the regressor models

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_LR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score: 0.158822016773438
# R2 score on training data: 8.103471183284528
# Mean Absolute Error: 2.740821327250652
# Mean Squared Error: 11.823380593643634
# Root Mean Squared Error: 3.4385143003401386

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_RFR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_RFR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2 score: 0.340739289476102
# R2 score on training data: 91.3762263215399
# Mean Absolute Error: 2.087304835493528
# Mean Squared Error: 9.266398367990279
# Root Mean Squared Error: 3.044075946488569

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print("R2 score:",r2_score(y_test,pred_knn))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error:",mean_squared_error(y_test,pred_knn))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2 score: 0.05638860119098943
# R2 score on training data: 52.79618320833925
# Mean Absolute Error: 2.619996229644401
# Mean Squared Error: 13.263158241285604
# Root Mean Squared Error: 3.641861919579819

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_GBR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_GBR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2 score: -0.025763457434909043
# R2 score on training data: 94.70867425388161
# Mean Absolute Error: 2.6020591248814746
# Mean Squared Error: 14.417866370901152
# Root Mean Squared Error: 3.797086563524876

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print("R2 score:",r2_score(y_test,pred_lasso))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error:",mean_squared_error(y_test,pred_lasso))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2 score: 0.017105477322643337
# R2 score on training data: 1.3582685007445083
# Mean Absolute Error: 2.8897853537319866
# Mean Squared Error: 13.81531168997805
# Root Mean Squared Error: 3.7168954370520098

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print("R2 score:",r2_score(y_test,pred_rd))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_rd))
print("Mean Squared Error:",mean_squared_error(y_test,pred_rd))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2 score: 0.15911242796168035
# R2 score on training data: 8.102727129195909
# Mean Absolute Error: 2.739983910910898
# Mean Squared Error: 11.819298648947374
# Root Mean Squared Error: 3.4379206868319945

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_train=dtr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_dtr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_dtr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_dtr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2 score: -0.5182612557317627
# R2 score on training data: 100.0
# Mean Absolute Error: 2.6815342306414083
# Mean Squared Error: 21.340288292192547
# Root Mean Squared Error: 4.619554988545168

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_svr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_svr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_svr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# R2 score: 0.25150504424671716
# R2 score on training data: 18.28091815219599
# Mean Absolute Error: 2.472853284158201
# Mean Squared Error: 10.520651884334846
# Root Mean Squared Error: 3.2435554387638956

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_etr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_etr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_etr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# R2 score: 0.3189707136790818
# R2 score on training data: 100.0
# Mean Absolute Error: 2.0266362426055156
# Mean Squared Error: 9.57237185013315
# Root Mean Squared Error: 3.0939249910321274

# %%
from sklearn.model_selection import cross_val_score

# %%
#Checking cvs for every model
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [-5.27376258e-02  6.77139638e-02 -1.78894090e+22 -3.44791820e-02
#  -7.60297376e-02]
# -3.5778818078506714e+21
# Difference between R2 score and CVS is: 3.577881807850671e+23

# %%
score=cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [-0.17329492 -0.00521017  0.18233634  0.42503402  0.07095798]
# 0.09996465218935328
# Difference between R2 score and CVS is: 24.077463728674868

# %%
score=cross_val_score(knn,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_knn)-score.mean())*100)
# Out:
# [-0.39723228 -0.0885889   0.19178458  0.21329779  0.08178317]
# 0.00020887092505719184
# Difference between R2 score and CVS is: 5.617973026593224

# %%
score=cross_val_score(lasso,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_lasso)-score.mean())*100)
# Out:
# [ 0.02058919 -0.09214031 -0.1651675  -0.00179879  0.01128609]
# -0.04544626371499152
# Difference between R2 score and CVS is: 6.255174103763486

# %%
score=cross_val_score(rd,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_rd)-score.mean())*100)
# Out:
# [-0.05050251  0.06798211 -0.11954397 -0.03350981 -0.0740599 ]
# -0.04192681542383596
# Difference between R2 score and CVS is: 20.103924338551632

# %%
score=cross_val_score(svr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_svr)-score.mean())*100)
# Out:
# [ 0.12484147  0.12634987 -0.14869938  0.00909683 -0.15043322]
# -0.007768887346136099
# Difference between R2 score and CVS is: 25.927393159285327

# %%
score=cross_val_score(etr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_etr)-score.mean())*100)
# Out:
# [-0.14610902 -0.19964736  0.10476655  0.22327399 -0.79228748]
# -0.16200066647407435
# Difference between R2 score and CVS is: 48.097138015315615

# %% [markdown]
# #In the models where the difference is coming high it means there is over fitting problem. Which means that the model is performing well on the training data but not very well on the unseen data.

# %%
##From the difference we conclude Linear Regression is the best performing model

# %% [markdown]
# ### HyperParameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'n_jobs':[-2,-1,1],'fit_intercept':[True,False],
      'positive':[False,True], 'copy_X':[True,False]}

# %%
gscv=GridSearchCV(LinearRegression(),param,cv=5)

# %%
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False], 'n_jobs': [-2, -1, 1],
#                          'positive': [False, True]})

# %%
gscv.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': -2, 'positive': True}

# %%
Model=LinearRegression(copy_X= True, fit_intercept= True, n_jobs= -2, positive= True)

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print("R2 score:",r2_score(y_test,pred))
print("Mean Absolute Error:",mean_absolute_error(y_test,pred))
print("Mean Squared Error:",mean_squared_error(y_test,pred))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 score: 0.10156382635866557
# Mean Absolute Error: 2.8008680985067818
# Mean Squared Error: 12.628186937695121
# Root Mean Squared Error: 3.5536160368975036

# %%
#We can use pickle to save model
import pickle
filename='Global_Powerplant.pkl'
pickle.dump(Model,open(filename, 'wb'))  #saved model

# %%
#loading the model

loaded_model=pickle.load(open('Global_Powerplant.pkl','rb'))  #read binary mode
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 10.156382635866557

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","original"])   #using[:] to get all the values of predicted data and actual data
conclusion
# Out:
#                   0          1          2          3          4          5   \
# Predicted  77.855665  79.415259  77.617853  78.012656  78.369193  77.520494
# original   74.800200  81.327400  77.670230  77.651500  74.801200  74.192400
#
#                   6         7          8          9   ...         49  \
# Predicted  78.126757  79.04546  77.306621  78.014567  ...  78.483699
# original   78.911800  73.35880  78.175300  72.898300  ...  77.151300
#
#                   50         51        52         53         54         55  \
# Predicted  77.085729  77.778129  76.66871  77.416291  78.186326  77.215513
# original   74.482100  72.929300  77.03090  73.591700  82.593400  76.337900
#
#                   56         57         58
# Predicted  78.271075  79.078693  78.729024
# original   80.537000  83.451300  76.781700
#
# [2 rows x 59 columns]

# %%
#These are the predictions of primary_fuel

# %% [markdown]
# #### Taking capacity_mw as target

# %%
#Checking the correlation of target variable only

df.corr()['capacity_mw'].sort_values(ascending=False)
# Out:
# 0
# capacity_mw     1.000000
# country         0.427231
# gppd_idnr       0.427227
# longitude      -0.222048
# primary_fuel   -0.279879
# latitude       -0.436740
# Name: capacity_mw, dtype: float64

# %%
#All the features are very less correlated to the target i.e. they do not contribute too much in its prediction

# %%
#Visualizing the correlation between the features and the label using bar plot

plt.figure(figsize=(22,7))
df.corr()['capacity_mw'].sort_values(ascending=False).drop(['capacity_mw']).plot(kind='bar',color='y')
plt.title("Correlation between features and label using bar plot",fontsize=20)
plt.xlabel("Features")
plt.ylabel("Target variable")
plt.show()

# %% [markdown]
# #### Seperating features and label

# %%
x=df.drop(['capacity_mw'],axis=1)
y=df["capacity_mw"]

# %%
print("Feature dimensions:",x.shape)
print("Target dimensions:",y.shape)
# Out:
# Feature dimensions: (196, 5)
# Target dimensions: (196,)

# %%
x
# Out:
# 0    country  gppd_idnr  latitude  longitude  primary_fuel
# 1      690.0        0.0  2.302585    16.9171       74.4821
# 2      691.0        1.0  2.525729    16.8810       74.5898
# 3      692.0        2.0  4.787492    31.2642       78.4835
# 4      693.0        3.0  7.200425    23.3026       81.0668
# 5      694.0        4.0  3.258097    16.2478       74.5003
# ..       ...        ...       ...        ...           ...
# 214    903.0      213.0  4.669084    13.1156       77.5838
# 215    904.0      214.0  7.377759    16.2949       77.3568
# 217    906.0      216.0  3.238678    15.2758       75.5811
# 218    907.0      217.0  4.382027    24.3500       73.7477
# 219    908.0      218.0  2.803360     9.9344       77.4768
#
# [196 rows x 5 columns]

# %% [markdown]
# #### Feature scaling using standard scalarisation

# %%
#To remove the biasness

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
# 0     country  gppd_idnr  latitude  longitude  primary_fuel
# 0   -1.694071  -1.694071 -1.096758  -0.459875     -0.767944
# 1   -1.678537  -1.678537 -0.983909  -0.465711     -0.743608
# 2   -1.663003  -1.663003  0.159910   1.859432      0.136229
# 3   -1.647469  -1.647469  1.380179   0.572385      0.719962
# 4   -1.631935  -1.631935 -0.613536  -0.568072     -0.763832
# ..        ...        ...       ...        ...           ...
# 191  1.614657   1.614657  0.100028  -1.074413     -0.067071
# 192  1.630191   1.630191  1.469860  -0.560458     -0.118365
# 193  1.661259   1.661259 -0.623356  -0.725202     -0.519610
# 194  1.676793   1.676793 -0.045142   0.741704     -0.933892
# 195  1.692327   1.692327 -0.843505  -1.588676     -0.091249
#
# [196 rows x 5 columns]

# %% [markdown]
# #### Checking Variance Inflation Factor

# %%
#Checking Vif in every scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#       VIF values      Features
# 0  407264.219399       country
# 1  407261.804262     gppd_idnr
# 2       1.089546      latitude
# 3       1.061553     longitude
# 4       1.072074  primary_fuel

# %% [markdown]
# #VIF is very high in country and gppd_idnr. VIF till 5 is fine. But as we only have 5 columns here and if we remove even 1 column we can lose 20% of our data so we cannot remove the whole column here.

# %% [markdown]
# #### Modelling

# %%
#Importing libraries

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Creating train test split

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum R2 score is:",maxAccu,"on random state",maxRS)
# Out:
# Maximum R2 score is: 0.5747943814142173 on random state 125

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
#Importing all the regressor models

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_LR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score: 0.5747943814142173
# R2 score on training data: 34.405817610637946
# Mean Absolute Error: 32.16138730337632
# Mean Squared Error: 1739.1828371331094
# Root Mean Squared Error: 41.70351108879334

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_RFR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_RFR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2 score: 0.4270645083080946
# R2 score on training data: 94.13573341014634
# Mean Absolute Error: 30.41898305084746
# Mean Squared Error: 2343.4299322033894
# Root Mean Squared Error: 48.40898606873924

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print("R2 score:",r2_score(y_test,pred_knn))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error:",mean_squared_error(y_test,pred_knn))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2 score: 0.5550564466659109
# R2 score on training data: 63.92037639776499
# Mean Absolute Error: 30.54576271186441
# Mean Squared Error: 1819.915254237288
# Root Mean Squared Error: 42.66046476818189

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_GBR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_GBR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2 score: 0.26232449022057325
# R2 score on training data: 97.69629949007458
# Mean Absolute Error: 34.16184719434423
# Mean Squared Error: 3017.2521949471093
# Root Mean Squared Error: 54.92952025047287

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print("R2 score:",r2_score(y_test,pred_lasso))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error:",mean_squared_error(y_test,pred_lasso))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2 score: 0.5631523639681174
# R2 score on training data: 34.25107159041865
# Mean Absolute Error: 33.10490727783794
# Mean Squared Error: 1786.8012035112486
# Root Mean Squared Error: 42.2705713648544

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print("R2 score:",r2_score(y_test,pred_rd))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_rd))
print("Mean Squared Error:",mean_squared_error(y_test,pred_rd))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2 score: 0.5733323411704188
# R2 score on training data: 34.3372571010589
# Mean Absolute Error: 32.27913387722411
# Mean Squared Error: 1745.1628975746185
# Root Mean Squared Error: 41.77514688872582

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_train=dtr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_dtr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_dtr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_dtr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2 score: -0.3688390580671137
# R2 score on training data: 100.0
# Mean Absolute Error: 43.898305084745765
# Mean Squared Error: 5598.847457627118
# Root Mean Squared Error: 74.82544659156481

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_svr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_svr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_svr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# R2 score: 0.1328651473693464
# R2 score on training data: 8.77734925139475
# Mean Absolute Error: 50.51988716079287
# Mean Squared Error: 3546.7688742944715
# Root Mean Squared Error: 59.554755261813234

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_etr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_etr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_etr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# R2 score: 0.6355146597474568
# R2 score on training data: 100.0
# Mean Absolute Error: 27.783220338983043
# Mean Squared Error: 1490.8237813559324
# Root Mean Squared Error: 38.61118725649255

# %%
from sklearn.model_selection import cross_val_score

# %%
#Checking cvs for every model
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [ 0.10003923  0.28810046 -0.5880453   0.24937026  0.32237529]
# 0.0743679868295924
# Difference between R2 score and CVS is: 50.04263945846249

# %%
score=cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [ 0.20877463  0.1928167  -1.68603979  0.00481021  0.16017016]
# -0.22389361712761552
# Difference between R2 score and CVS is: 65.09581254357101

# %%
score=cross_val_score(knn,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_knn)-score.mean())*100)
# Out:
# [-0.32405994 -0.14811446 -1.96504458 -0.21144595 -0.14441631]
# -0.5586162464776574
# Difference between R2 score and CVS is: 111.36726931435683

# %%
score=cross_val_score(GBR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [ 0.09172891  0.19485381 -1.48586978  0.12339953  0.12204041]
# -0.1907694223507793
# Difference between R2 score and CVS is: 45.30939125713525

# %%
score=cross_val_score(lasso,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_lasso)-score.mean())*100)
# Out:
# [ 0.08231865  0.27531466 -0.51514439  0.23887812  0.34613942]
# 0.08550129098546963
# Difference between R2 score and CVS is: 47.76510729826477

# %%
score=cross_val_score(rd,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_rd)-score.mean())*100)
# Out:
# [ 0.09847839  0.28605517 -0.58056572  0.25036902  0.32578443]
# 0.07602426034811952
# Difference between R2 score and CVS is: 49.73080808222993

# %%
score=cross_val_score(dtr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_dtr)-score.mean())*100)
# Out:
# [-0.64038762 -0.28295844 -2.23398518 -0.5292442  -0.7079626 ]
# -0.8789076089243986
# Difference between R2 score and CVS is: 51.00685508572849

# %%
score=cross_val_score(svr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_svr)-score.mean())*100)
# Out:
# [-0.31350952  0.00271431 -0.31738404 -0.22821202 -2.46203316]
# -0.6636848859087945
# Difference between R2 score and CVS is: 79.65500332781409

# %%
score=cross_val_score(etr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_etr)-score.mean())*100)
# Out:
# [ 0.19062414 -0.05287129 -0.78329543  0.05442046  0.18720413]
# -0.08078360051620748
# Difference between R2 score and CVS is: 71.62982602636643

# %% [markdown]
# #In the models where the difference is coming high it means there is over fitting problem. Which means that the model is performing well on the training data but not very well on the unseen data.

# %%
#From the difference we conclude GBR is the best performing model

# %% [markdown]
# #### HyperParameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'loss':['squared_error', 'absolute_error', 'huber', 'quantile'],'random_state': [10,50,1000],
      'n_estimators':[50,100,200,300],
      'criterion':['friedman_mse', 'squared_error'],
      'warm_start':[True, False]}

# %%
gscv=GridSearchCV(GradientBoostingRegressor(),param,cv=5)

# %%
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['friedman_mse', 'squared_error'],
#                          'loss': ['squared_error', 'absolute_error', 'huber',
#                                   'quantile'],
#                          'n_estimators': [50, 100, 200, 300],
#                          'random_state': [10, 50, 1000],
#                          'warm_start': [True, False]})

# %%
gscv.best_params_
# Out:
# {'criterion': 'squared_error',
#  'loss': 'squared_error',
#  'n_estimators': 300,
#  'random_state': 10,
#  'warm_start': True}

# %%
Model=GradientBoostingRegressor(criterion= 'squared_error',
 loss= 'squared_error',
 n_estimators= 300,
 random_state= 10,
 warm_start= True)

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print("R2 score:",r2_score(y_test,pred))
print("Mean Absolute Error:",mean_absolute_error(y_test,pred))
print("Mean Squared Error:",mean_squared_error(y_test,pred))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 score: 0.23590755843912603
# Mean Absolute Error: 34.62636450642576
# Mean Squared Error: 3125.303152779738
# Root Mean Squared Error: 55.90441085263074

# %%
import pickle
filename='Global_power_plant.pkl'
pickle.dump(Model,open(filename, 'wb'))  #saved model

# %%
#loading the model

loaded_model=pickle.load(open('Global_power_plant.pkl','rb'))  #read binary mode
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 23.590755843912603

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","original"])  
conclusion
# Out:
#                   0           1           2          3           4   \
# Predicted  66.483541  127.949393  185.699911  76.637603  147.444931
# original   62.000000  156.000000   20.000000  73.000000  152.000000
#
#                    5          6           7           8           9   ...  \
# Predicted  177.784983  85.375976  125.134978  175.707019  192.639263  ...
# original    40.000000  91.000000   19.000000  149.000000   42.000000  ...
#
#                    49          50       51        52          53         54  \
# Predicted  135.248731  140.818162  94.7523  83.76618  201.686443  29.806807
# original   115.000000  151.000000  98.0000  81.00000  192.000000   8.000000
#
#                   55          56          57          58
# Predicted  48.668739  175.791841  130.306744  107.649821
# original   47.000000  195.000000  111.000000  146.000000
#
# [2 rows x 59 columns]

# %%
#These are the predictions for capacity_mw
