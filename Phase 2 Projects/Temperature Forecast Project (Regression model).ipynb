# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#loading the dataset


df=pd.read_csv('temp.csv')
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df.head()  #top 5 rows
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
df.tail()  #last 5 rows
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# ...

# %%
df.shape   #Dimensions
# Out:
# (7752, 25)

# %%
df.columns.to_list()   #All the columns
# Out:
# ['station',
#  'Date',
#  'Present_Tmax',
#  'Present_Tmin',
#  'LDAPS_RHmin',
#  'LDAPS_RHmax',
#  'LDAPS_Tmax_lapse',
#  'LDAPS_Tmin_lapse',
#  'LDAPS_WS',
#  'LDAPS_LH',
#  'LDAPS_CC1',
#  'LDAPS_CC2',
#  'LDAPS_CC3',
#  'LDAPS_CC4',
#  'LDAPS_PPT1',
#  'LDAPS_PPT2',
#  'LDAPS_PPT3',
#  'LDAPS_PPT4',
#  'lat',
#  'lon',
#  'DEM',
#  'Slope',
#  'Solar radiation',
#  'Next_Tmax',
#  'Next_Tmin']

# %%
df.dtypes  #Datatypes of all the columns
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
#We can see that Date column has object dtype which is not correct, will change it to datetime dtype

# %%
df["Date"]=pd.to_datetime(df['Date'], format='%d-%m-%Y')  #because in my df date is given in this format d-m-y

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   datetime64[ns]
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
# ...

# %%
#Now we can see datetime dtype for Date column

# %%
#Setting Date as dataframe index

df.set_index('Date',inplace=True)

#The set_index() function is used to set the Date frame index using existing columns

# %% [markdown]
# #Data Preprocessing

# %%
#Dropping columns that are not required

# %%
#Dropping 'station'. This column represents the weather station number and is not relevant and can potentially be dropped.

df.drop("station",axis=1,inplace=True)

# %% [markdown]
# #Dropping lat and lon. These columns represent the latitude and longitude coordinates. While they may be relevant for understanding the geographical location, they might not directly influence the temperature predictions.

# %%
df.drop("lat",axis=1,inplace=True)
df.drop("lon",axis=1,inplace=True)

# %%
df
# Out:
#             Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Date
# 2013-06-30          28.7          21.4    58.255688    91.116364
# 2013-06-30          31.9          21.6    52.263397    90.604721
# 2013-06-30          31.6          23.3    48.690479    83.973587
# 2013-06-30          32.0          23.4    58.239788    96.483688
# 2013-06-30          31.4          21.9    56.174095    90.155128
# ...                  ...           ...          ...          ...
# 2017-08-30          23.3          17.1    26.741310    78.869858
# 2017-08-30          23.3          17.7    24.040634    77.294975
# 2017-08-30          23.2          17.4    22.933014    77.243744
# NaT                 20.0          11.3    19.794666    58.936283
# NaT                 37.6          29.9    98.524734   100.000153
#
#             LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# Date
# 2013-06-30         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df.dtypes
# Out:
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
#All the columns have float dtype now

# %%
df.isnull().sum()
# Out:
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
#We can see a lot of columns with null values, will fill in the null values with the mean of that very column

# %%
df['Present_Tmax']=df['Present_Tmax'].fillna(df['Present_Tmax'].mean())

# %%
df['Present_Tmin']=df['Present_Tmin'].fillna(df['Present_Tmin'].mean())

# %%
df['LDAPS_RHmin']=df['LDAPS_RHmin'].fillna(df['LDAPS_RHmin'].mean())

# %%
df['LDAPS_RHmax']=df['LDAPS_RHmax'].fillna(df['LDAPS_RHmax'].mean())

# %%
df['LDAPS_Tmax_lapse']=df['LDAPS_Tmax_lapse'].fillna(df['LDAPS_Tmax_lapse'].mean())

# %%
df['LDAPS_Tmin_lapse']=df['LDAPS_Tmin_lapse'].fillna(df['LDAPS_Tmin_lapse'].mean())

# %%
df['LDAPS_WS']=df['LDAPS_WS'].fillna(df['LDAPS_WS'].mean())

# %%
df['LDAPS_LH']=df['LDAPS_LH'].fillna(df['LDAPS_LH'].mean())

# %%
df['LDAPS_CC1']=df['LDAPS_CC1'].fillna(df['LDAPS_CC1'].mean())

# %%
df['LDAPS_CC2']=df['LDAPS_CC2'].fillna(df['LDAPS_CC2'].mean())

# %%
df['LDAPS_CC3']=df['LDAPS_CC3'].fillna(df['LDAPS_CC3'].mean())

# %%
df['LDAPS_CC4']=df['LDAPS_CC4'].fillna(df['LDAPS_CC4'].mean())

# %%
df['LDAPS_PPT1']=df['LDAPS_PPT1'].fillna(df['LDAPS_PPT1'].mean())

# %%
df['LDAPS_PPT2']=df['LDAPS_PPT2'].fillna(df['LDAPS_PPT2'].mean())

# %%
df['LDAPS_PPT3']=df['LDAPS_PPT3'].fillna(df['LDAPS_PPT3'].mean())

# %%
df['LDAPS_PPT4']=df['LDAPS_PPT4'].fillna(df['LDAPS_PPT4'].mean())

# %%
df['Next_Tmax']=df['Next_Tmax'].fillna(df['Next_Tmax'].mean())

# %%
df['Next_Tmin']=df['Next_Tmin'].fillna(df['Next_Tmin'].mean())

# %%
#Again checking null values


df.isnull().sum()
# Out:
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
#no more null values

# %%
#Checking number of unique values in each column
df.nunique().to_frame("No. of unique values")
# Out:
#                   No. of unique values
# Present_Tmax                       168
# Present_Tmin                       156
# LDAPS_RHmin                       7673
# LDAPS_RHmax                       7665
# LDAPS_Tmax_lapse                  7676
# LDAPS_Tmin_lapse                  7676
# LDAPS_WS                          7676
# LDAPS_LH                          7676
# LDAPS_CC1                         7570
# LDAPS_CC2                         7583
# LDAPS_CC3                         7600
# LDAPS_CC4                         7525
# LDAPS_PPT1                        2813
# LDAPS_PPT2                        2511
# LDAPS_PPT3                        2357
# LDAPS_PPT4                        1919
# DEM                                 25
# Slope                               27
# Solar radiation                   1575
# Next_Tmax                          184
# Next_Tmin                          158

# %%
#All columns are continous columns as all columns have many unique values

# %%
#checking the value counts of unique values in each column

for i in df.columns:
    print(df[i].value_counts())
    print('\n')  #new line
# Out:
# 31.4    112
# 29.4    111
# 29.1    108
# 29.7    107
# 31.9    105
#        ...
# 36.9      1
# 21.2      1
# 20.1      1
# 36.4      1
# 20.3      1
# Name: Present_Tmax, Length: 168, dtype: int64
#
#
# 24.0    161
# 23.8    153
# 23.1    144
# 23.5    143
# 23.3    142
#        ...
# 13.6      1
# 14.2      1
# 29.1      1
# 29.7      1
# 15.0      1
# Name: Present_Tmin, Length: 156, dtype: int64
#
#
# 56.759372    75
# 77.030350     2
# 98.524734     2
# 19.794666     2
# 51.810596     2
#              ..
# 52.924568     1
# 60.215191     1
# 46.799820     1
# 52.227486     1
# 22.933014     1
# Name: LDAPS_RHmin, Length: 7673, dtype: int64
#
#
# 88.374804     75
# 96.525200      2
# 99.251968      2
# 100.000153     2
# 94.795967      2
#               ..
# 96.718201      1
# 94.153252      1
# 96.910126      1
# 93.541885      1
# 77.243744      1
# Name: LDAPS_RHmax, Length: 7665, dtype: int64
#
#
# 29.613447    75
# 17.624954     2
# 38.542255     2
# 28.074101     1
# ...

# %%
print("Total duplicate rows are:",df.duplicated().sum())   #This function is used to check the duplicate rows in the df
# Out:
# Total duplicate rows are: 0

# %%
df.describe()   #Statistical summary
# Out:
#        Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# count   7752.000000   7752.000000  7752.000000  7752.000000       7752.000000
# mean      29.768211     23.225059    56.759372    88.374804         29.613447
# std        2.956557      2.403036    14.596973     7.157124          2.932898
# min       20.000000     11.300000    19.794666    58.936283         17.624954
# 25%       27.800000     21.700000    46.046162    84.316923         27.693091
# 50%       29.900000     23.400000    55.313244    89.699505         29.662273
# 75%       32.000000     24.900000    67.038254    93.704500         31.683819
# max       37.600000     29.900000    98.524734   100.000153         38.542255
#
#        LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH    LDAPS_CC1    LDAPS_CC2  \
# count       7752.000000  7752.000000  7752.000000  7752.000000  7752.000000
# mean          23.512589     7.097875    62.505019     0.368774     0.356080
# ...

# %%
#Count of all the columns is same
#Difference between max and 75% values are too much which indicates outliers

# %%
plt.figure(figsize=(22,10))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linewidth=1,linecolor='black',cmap='Spectral')
plt.xlabel('Figure',fontsize=14)
plt.ylabel("Features_name",fontsize=14)
plt.title("Descriptive Graph",fontsize=20)
plt.show()

# %%
#Creating lmplot of all the the feature variable with the label variable

sns.lmplot(x='Present_Tmax',y='Next_Tmax',data=df)

# %%
#Present day max temp and the next day max temp are positively correlated

# %%
sns.lmplot(x='Present_Tmin',y='Next_Tmin',data=df)

# %%
#Present day min temp and the next day min temp are positively correlated

# %%
sns.lmplot(x='LDAPS_RHmax',y='Next_Tmax',data=df)

# %%
#next-day maximum relative humidity is negatively correlated to the max temp next day

# %%
plt.figure(figsize=(20,15))
p=1
for i in df.columns:
    if p<=45:    
        plt.subplot(5,9,p) 
        sns.regplot(x='Next_Tmax',y=i,data=df,color='r')
        plt.xlabel("Next_Tmax")
        plt.ylabel(i)
    p+=1
plt.show()

# %%
plt.figure(figsize=(20,15))
p=1
for i in df.columns:
    if p<=45:    
        plt.subplot(5,9,p) 
        sns.regplot(x='Next_Tmin',y=i,data=df,color='r')
        plt.xlabel("Next_Tmin")
        plt.ylabel(i)
    p+=1
plt.show()

# %%
#Let's check the outliers by plotting the boxplot

plt.figure(figsize=(25,25))
p=1
for i in df.columns:
    if p<=45:
        plt.subplot(5,9,p)
        sns.boxplot(df[i],palette="Set2_r")
        plt.xlabel(i)
    p+=1
plt.show()

# %% [markdown]
# #We can see outliers in almost all the columns except few. However we will not remove outliers from next_Tmax and min as they are target variables

# %%
#Removing outliers by Z score

from scipy.stats import zscore
out_features=df[[
 'Present_Tmax',
 'Present_Tmin',
 'LDAPS_RHmax',
 'LDAPS_Tmax_lapse',
 'LDAPS_Tmin_lapse',
 'LDAPS_WS',
 'LDAPS_LH',
 'LDAPS_PPT1',
 'LDAPS_PPT2',
 'LDAPS_PPT3',
 'LDAPS_PPT4',
 'DEM',
 'Slope',
 ]]
z=np.abs(zscore(out_features))  
z
# Out:
#             Present_Tmax  Present_Tmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# Date
# 2013-06-30      0.361326      0.759529     0.383078          0.524889
# 2013-06-30      0.721084      0.676296     0.311586          0.080895
# 2013-06-30      0.619608      0.031188     0.614982          0.162936
# 2013-06-30      0.754909      0.072805     1.133054          0.031092
# 2013-06-30      0.551957      0.551446     0.248765          0.170325
# ...                  ...           ...          ...               ...
# 2017-08-30      2.187892      2.549048     1.328126          1.112066
# 2017-08-30      2.187892      2.299348     1.548184          0.887662
# 2017-08-30      2.221718      2.424198     1.555342          0.570780
# NaT             3.304127      4.962817     4.113443          4.087857
# NaT             2.649126      2.777891     1.624409          3.044561
#
#             LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_PPT1  LDAPS_PPT2  \
# Date
# ...

# %%
#threshold=3

np.where(z>3)
# Out:
# (array([  25,   25,   26, ..., 7751, 7751, 7751], dtype=int64),
#  array([ 5,  8,  8, ...,  8,  9, 10], dtype=int64))

# %%
#Now removing the data above Z score and creating a new df

df1=df[(z<3).all(axis=1)]  
df1
# Out:
#             Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Date
# 2013-06-30          28.7          21.4    58.255688    91.116364
# 2013-06-30          31.9          21.6    52.263397    90.604721
# 2013-06-30          31.6          23.3    48.690479    83.973587
# 2013-06-30          32.0          23.4    58.239788    96.483688
# 2013-06-30          31.4          21.9    56.174095    90.155128
# ...                  ...           ...          ...          ...
# 2017-08-30          23.1          17.8    24.688997    78.261383
# 2017-08-30          22.5          17.4    30.094858    83.690018
# 2017-08-30          23.3          17.1    26.741310    78.869858
# 2017-08-30          23.3          17.7    24.040634    77.294975
# 2017-08-30          23.2          17.4    22.933014    77.243744
#
#             LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  \
# Date
# 2013-06-30         28.074101         23.006936  6.818887   69.451805
# ...

# %%
print("Old dataframe",df.shape[0])  #df.shape[0] will give only the rows
print("New dataframe",df1.shape[0])
# Out:
# Old dataframe 7752
# New dataframe 6907

# %%
#Checking the data loss percentage after removing the outliers

print("Data Loss Percentage:", ((df.shape[0]-df1.shape[0])/df.shape[0])*100)    #Change in data/original data *100
# Out:
# Data Loss Percentage: 10.900412796697626

# %%
#Now lets check with IQR method:

#1st Quantile
Q1=out_features.quantile(0.25)

#3rd Quantile
Q3=out_features.quantile(0.75)

IQR=Q3-Q1

df2=df[~((df < (Q1-1.5*IQR))|(df> (Q3+ 1.5*IQR))).any(axis=1)]

# %%
df2.shape
# Out:
# (3272, 21)

# %%
print("Data Loss Percentage:", ((df.shape[0]-df2.shape[0])/df.shape[0])*100)    #Change in data/original data *100
# Out:
# Data Loss Percentage: 57.791537667698655

# %% [markdown]
# #This means both methods of removing outliers are acceptable. We can go ahead with any one of these. We will choose z score method as its giving less data loss comparatively.

# %%
df=df1

# %%
df
# Out:
#             Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Date
# 2013-06-30          28.7          21.4    58.255688    91.116364
# 2013-06-30          31.9          21.6    52.263397    90.604721
# 2013-06-30          31.6          23.3    48.690479    83.973587
# 2013-06-30          32.0          23.4    58.239788    96.483688
# 2013-06-30          31.4          21.9    56.174095    90.155128
# ...                  ...           ...          ...          ...
# 2017-08-30          23.1          17.8    24.688997    78.261383
# 2017-08-30          22.5          17.4    30.094858    83.690018
# 2017-08-30          23.3          17.1    26.741310    78.869858
# 2017-08-30          23.3          17.7    24.040634    77.294975
# 2017-08-30          23.2          17.4    22.933014    77.243744
#
#             LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  \
# Date
# 2013-06-30         28.074101         23.006936  6.818887   69.451805
# ...

# %%
#Checking skewness


df.skew()
# Out:
# Present_Tmax       -0.274967
# Present_Tmin       -0.232563
# LDAPS_RHmin         0.306629
# LDAPS_RHmax        -0.685714
# LDAPS_Tmax_lapse   -0.107855
# LDAPS_Tmin_lapse   -0.396956
# LDAPS_WS            1.085850
# LDAPS_LH            0.565799
# LDAPS_CC1           0.593987
# LDAPS_CC2           0.501474
# LDAPS_CC3           0.701971
# LDAPS_CC4           0.711892
# LDAPS_PPT1          3.735186
# LDAPS_PPT2          4.848692
# LDAPS_PPT3          5.484463
# LDAPS_PPT4          5.932870
# DEM                 1.761452
# Slope               1.592353
# Solar radiation    -0.503706
# Next_Tmax          -0.270276
# Next_Tmin          -0.293914
# dtype: float64

# %%
#We can see high skewness in LDAPS_RHmax ,LDAPS_CC3,LDAPS_CC4, LDAPS_PPT1, LDAPS_PPT2, LDAPS_PPT3, LDAPS_PPT4, DEM,Slope

# %%
import scipy.stats as stats

# %%
#Removing skewness using yeojohnson

df['LDAPS_RHmax'],lambda_=stats.yeojohnson(df['LDAPS_RHmax'])
df['LDAPS_CC3'],lambda_=stats.yeojohnson(df['LDAPS_CC3'])
df['LDAPS_CC4'],lambda_=stats.yeojohnson(df['LDAPS_CC4'])
df['LDAPS_PPT1'],lambda_=stats.yeojohnson(df['LDAPS_PPT1'])
df['LDAPS_PPT2'],lambda_=stats.yeojohnson(df['LDAPS_PPT2'])
df['LDAPS_PPT3'],lambda_=stats.yeojohnson(df['LDAPS_PPT4'])
df['LDAPS_PPT4'],lambda_=stats.yeojohnson(df['LDAPS_PPT4'])
df['DEM'],lambda_=stats.yeojohnson(df['DEM'])
df['Slope'],lambda_=stats.yeojohnson(df['Slope'])

# %%
#Checking skewness again


df.skew()
# Out:
# Present_Tmax       -0.274967
# Present_Tmin       -0.232563
# LDAPS_RHmin         0.306629
# LDAPS_RHmax        -0.098617
# LDAPS_Tmax_lapse   -0.107855
# LDAPS_Tmin_lapse   -0.396956
# LDAPS_WS            1.085850
# LDAPS_LH            0.565799
# LDAPS_CC1           0.593987
# LDAPS_CC2           0.501474
# LDAPS_CC3           0.090640
# LDAPS_CC4           0.137992
# LDAPS_PPT1          1.547163
# LDAPS_PPT2          1.738422
# LDAPS_PPT3          2.157941
# LDAPS_PPT4          2.157941
# DEM                 0.038646
# Slope               0.233614
# Solar radiation    -0.503706
# Next_Tmax          -0.270276
# Next_Tmin          -0.293914
# dtype: float64

# %%
#Skewness removed to a great extent

# %%
#Let's visualize after removing skewness

plt.figure(figsize=(20,25),facecolor='green')
plotnumber=1

for i in df.columns:   
    if plotnumber<=45:
        plt.subplot(5,9,plotnumber)
        sns.distplot(df[i],color='m')
        plt.xlabel(i,fontsize=20)
    plotnumber+=1
plt.show()

# %%
#Now we will check correlation 

df.corr()
# Out:
#                   Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Present_Tmax          1.000000      0.614395    -0.149083    -0.314166
# Present_Tmin          0.614395      1.000000     0.153622    -0.049832
# LDAPS_RHmin          -0.149083      0.153622     1.000000     0.566537
# LDAPS_RHmax          -0.314166     -0.049832     0.566537     1.000000
# LDAPS_Tmax_lapse      0.535406      0.436104    -0.552112    -0.401663
# LDAPS_Tmin_lapse      0.610636      0.755003     0.135762    -0.155136
# LDAPS_WS             -0.106335      0.017166     0.239855     0.113658
# LDAPS_LH              0.127053     -0.007450    -0.039676     0.258770
# LDAPS_CC1            -0.284372      0.092169     0.576662     0.428297
# LDAPS_CC2            -0.152768      0.120491     0.715239     0.374780
# LDAPS_CC3            -0.057712      0.049034     0.639376     0.147237
# LDAPS_CC4            -0.047638      0.006088     0.460949     0.050732
# ...

# %%
#Visualizing it on the heatmap

plt.figure(figsize=(40,40))
sns.heatmap(df.corr(),annot=True,fmt='0.2f',linewidth=1,linecolor='black',cmap='Blues')
plt.xlabel("Figure")
plt.ylabel("Features name")
plt.title("Descriptive Graph")
plt.show()

# %% [markdown]
# #So many independent variables have high correlation with other independent variables so there's a problem of multicolliniarity.

# %% [markdown]
# ### 1.Predicting Next day's max temp

# %%
#Checking the correlation of target variable only

df.corr()['Next_Tmax'].sort_values(ascending=False)
# Out:
# Next_Tmax           1.000000
# LDAPS_Tmax_lapse    0.806117
# Present_Tmax        0.587102
# Next_Tmin           0.584606
# LDAPS_Tmin_lapse    0.540175
# Present_Tmin        0.448868
# LDAPS_LH            0.169936
# Solar radiation    -0.027880
# Slope              -0.086869
# DEM                -0.120277
# LDAPS_PPT4         -0.172203
# LDAPS_PPT3         -0.172203
# LDAPS_WS           -0.276668
# LDAPS_PPT1         -0.308524
# LDAPS_PPT2         -0.310962
# LDAPS_RHmax        -0.320951
# LDAPS_CC4          -0.405844
# LDAPS_RHmin        -0.424992
# LDAPS_CC1          -0.446244
# LDAPS_CC3          -0.453363
# LDAPS_CC2          -0.475584
# Name: Next_Tmax, dtype: float64

# %%
#We can see that LDAPS_Tmax_lapse is highly correlated with the target i.e. it is contribiting too much in its prediction

# %%
#Visualizing the correlation between the features and the label using bar plot

plt.figure(figsize=(22,7))
df.corr()['Next_Tmax'].sort_values(ascending=False).drop(['Next_Tmax']).plot(kind='bar',color='y')
plt.title("Correlation between features and label using bar plot",fontsize=20)
plt.xlabel("Features")
plt.ylabel("Target variable")
plt.show()

# %% [markdown]
# #### Seperating features and label

# %%
x=df.drop(['Next_Tmax'],axis=1)
y=df["Next_Tmax"]

# %%
x
# Out:
#             Present_Tmax  Present_Tmin  LDAPS_RHmin   LDAPS_RHmax  \
# Date
# 2013-06-30          28.7          21.4    58.255688  3.010904e+08
# 2013-06-30          31.9          21.6    52.263397  2.933820e+08
# 2013-06-30          31.6          23.3    48.690479  2.067649e+08
# 2013-06-30          32.0          23.4    58.239788  3.919422e+08
# 2013-06-30          31.4          21.9    56.174095  2.867371e+08
# ...                  ...           ...          ...           ...
# 2017-08-30          23.1          17.8    24.688997  1.495373e+08
# 2017-08-30          22.5          17.4    30.094858  2.035715e+08
# 2017-08-30          23.3          17.1    26.741310  1.549582e+08
# 2017-08-30          23.3          17.7    24.040634  1.412346e+08
# 2017-08-30          23.2          17.4    22.933014  1.408048e+08
#
#             LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  \
# Date
# 2013-06-30         28.074101         23.006936  6.818887   69.451805
# ...

# %%
print("Feature dimensions:",x.shape)
print("Target dimensions:",y.shape)
# Out:
# Feature dimensions: (6907, 20)
# Target dimensions: (6907,)

# %% [markdown]
# #### Feature scaling using standard scalarisation

# %%
#To remove the biasness

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0        -0.430760     -0.821754     0.193211     0.349662         -0.659354
# 1         0.688750     -0.735346    -0.240045     0.261904         -0.010082
# 2         0.583796     -0.000870    -0.498375    -0.724195          0.077849
# 3         0.723735      0.042335     0.192061     1.383971         -0.063461
# 4         0.513827     -0.605732     0.042707     0.186255         -0.279337
# ...            ...           ...          ...          ...               ...
# 6902     -2.389904     -2.377115    -2.233737    -1.375707         -0.754887
# 6903     -2.599813     -2.549933    -1.842881    -0.760551         -1.159742
# 6904     -2.319935     -2.679546    -2.085350    -1.313992         -1.288685
# 6905     -2.319935     -2.420320    -2.280615    -1.470229         -1.048171
# 6906     -2.354920     -2.549933    -2.360699    -1.475122         -0.708540
#
# ...

# %% [markdown]
# #### Checking Variance Inflation Factor

# %%
#Checking Vif in every scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#     VIF values          Features
# 0     2.720564      Present_Tmax
# 1     3.319971      Present_Tmin
# 2     5.889209       LDAPS_RHmin
# 3     2.393135       LDAPS_RHmax
# 4     6.514014  LDAPS_Tmax_lapse
# 5     8.262898  LDAPS_Tmin_lapse
# 6     1.205474          LDAPS_WS
# 7     1.489809          LDAPS_LH
# 8     4.694146         LDAPS_CC1
# 9     5.448515         LDAPS_CC2
# 10    4.245758         LDAPS_CC3
# 11    2.690553         LDAPS_CC4
# 12    2.587540        LDAPS_PPT1
# 13    2.079198        LDAPS_PPT2
# 14         inf        LDAPS_PPT3
# 15         inf        LDAPS_PPT4
# 16    2.781477               DEM
# 17    2.677204             Slope
# 18    1.226879   Solar radiation
# 19    5.286760         Next_Tmin

# %%
#Dropping columns LDAPS_PPT3 and LDAPS_PPT4 as there vif is infinity

# %%
x.drop("LDAPS_PPT3",axis=1,inplace=True)
x.drop("LDAPS_PPT4",axis=1,inplace=True)

# %%
#Again Checking Vif 

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#     VIF values          Features
# 0     2.687368      Present_Tmax
# 1     3.314210      Present_Tmin
# 2     5.877786       LDAPS_RHmin
# 3     2.383152       LDAPS_RHmax
# 4     6.417842  LDAPS_Tmax_lapse
# 5     8.183486  LDAPS_Tmin_lapse
# 6     1.177128          LDAPS_WS
# 7     1.489120          LDAPS_LH
# 8     4.687753         LDAPS_CC1
# 9     5.405207         LDAPS_CC2
# 10    4.184132         LDAPS_CC3
# 11    2.500591         LDAPS_CC4
# 12    2.574553        LDAPS_PPT1
# 13    2.062719        LDAPS_PPT2
# 14    2.780604               DEM
# 15    2.676515             Slope
# 16    1.215700   Solar radiation
# 17    5.285044         Next_Tmin

# %%
#Dropping LDAPS_Tmin_lapse as it contains high vif

x.drop("LDAPS_Tmin_lapse",axis=1,inplace=True)

# %%
#Again Checking Vif 

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#     VIF values          Features
# 0     2.587835      Present_Tmax
# 1     3.217626      Present_Tmin
# 2     4.638357       LDAPS_RHmin
# 3     2.324276       LDAPS_RHmax
# 4     4.098895  LDAPS_Tmax_lapse
# 5     1.174229          LDAPS_WS
# 6     1.416261          LDAPS_LH
# 7     4.556539         LDAPS_CC1
# 8     5.382094         LDAPS_CC2
# 9     4.177502         LDAPS_CC3
# 10    2.498516         LDAPS_CC4
# 11    2.533033        LDAPS_PPT1
# 12    2.060949        LDAPS_PPT2
# 13    2.728512               DEM
# 14    2.621458             Slope
# 15    1.208721   Solar radiation
# 16    4.242955         Next_Tmin

# %%
#Vif decreased  so the problem of multicolliniarity is solved

# %% [markdown]
# #### Modelling

# %%
#Importing libraries

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Creating train test split

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum R2 score is:",maxAccu,"on random state",maxRS)
# Out:
# Maximum R2 score is: 0.7779916331064671 on random state 178

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
#Importing all the regressor models

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_LR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score: 0.7779916331064671
# R2 score on training data: 75.56933678512914
# Mean Absolute Error: 1.0637788510066781
# Mean Squared Error: 1.9366228377283645
# Root Mean Squared Error: 1.391625969047849

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR,y=y_test,color='r')
plt.plot(pred_LR,pred_LR,color='b')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Linear regression")
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_RFR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_RFR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2 score: 0.8957591873255132
# R2 score on training data: 98.35423035064686
# Mean Absolute Error: 0.7152896975600922
# Mean Squared Error: 0.9093131996488559
# Root Mean Squared Error: 0.953579152272561

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print("R2 score:",r2_score(y_test,pred_knn))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error:",mean_squared_error(y_test,pred_knn))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2 score: 0.8819368923807412
# R2 score on training data: 91.59329305860285
# Mean Absolute Error: 0.7558923936511505
# Mean Squared Error: 1.0298878087702321
# Root Mean Squared Error: 1.014833882352295

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_GBR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_GBR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2 score: 0.8565636145923942
# R2 score on training data: 86.09439295650476
# Mean Absolute Error: 0.861366428893775
# Mean Squared Error: 1.2512239229019293
# Root Mean Squared Error: 1.118581209792981

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print("R2 score:",r2_score(y_test,pred_lasso))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error:",mean_squared_error(y_test,pred_lasso))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2 score: 0.5313576534798059
# R2 score on training data: 53.023806529292926
# Mean Absolute Error: 1.603190534970418
# Mean Squared Error: 4.088059759625465
# Root Mean Squared Error: 2.021895091152225

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print("R2 score:",r2_score(y_test,pred_rd))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_rd))
print("Mean Squared Error:",mean_squared_error(y_test,pred_rd))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2 score: 0.777996803389021
# R2 score on training data: 75.56933393687963
# Mean Absolute Error: 1.0637614413248393
# Mean Squared Error: 1.936577736332361
# Root Mean Squared Error: 1.3916097643852465

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_train=dtr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_dtr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_dtr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_dtr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2 score: 0.7644783896996797
# R2 score on training data: 100.0
# Mean Absolute Error: 1.0239749155812832
# Mean Squared Error: 2.054501529236946
# Root Mean Squared Error: 1.4333532464947174

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_svr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_svr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_svr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# R2 score: 0.8730372853234692
# R2 score on training data: 87.5600599833078
# Mean Absolute Error: 0.7783699348840142
# Mean Squared Error: 1.1075208390703322
# Root Mean Squared Error: 1.0523881598869935

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_etr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_etr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_etr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# R2 score: 0.9149263939949495
# R2 score on training data: 100.0
# Mean Absolute Error: 0.649234176505759
# Mean Squared Error: 0.7421138697727391
# Root Mean Squared Error: 0.8614603123607837

# %%
from sklearn.model_selection import cross_val_score

# %%
#Checking cvs for every model
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.71069969 0.66224    0.68711959 0.74056475 0.65936531]
# 0.69199786936528
# Difference between R2 score and CVS is: 8.599376374118716

# %%
score=cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [0.69151111 0.65544912 0.66649814 0.73066892 0.65686912]
# 0.6801992824887932
# Difference between R2 score and CVS is: 21.555990483671994

# %%
score=cross_val_score(knn,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_knn)-score.mean())*100)
# Out:
# [0.59753382 0.481551   0.45813761 0.61077283 0.59353768]
# 0.5483065891617099
# Difference between R2 score and CVS is: 33.36303032190313

# %%
score=cross_val_score(GBR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [0.68386144 0.66179096 0.66923865 0.77212711 0.65987071]
# 0.6893777733248612
# Difference between R2 score and CVS is: 16.7185841267533

# %%
score=cross_val_score(lasso,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_lasso)-score.mean())*100)
# Out:
# [0.46568419 0.46470373 0.55665833 0.37408339 0.52244343]
# 0.47671461312158925
# Difference between R2 score and CVS is: 5.464304035821666

# %%
score=cross_val_score(rd,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_rd)-score.mean())*100)
# Out:
# [0.71076289 0.6622417  0.68714169 0.74060431 0.65938702]
# 0.6920275205709098
# Difference between R2 score and CVS is: 8.596928281811122

# %%
score=cross_val_score(dtr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_dtr)-score.mean())*100)
# Out:
# [0.32272913 0.40912734 0.41097542 0.48787824 0.50053905]
# 0.42624983763082813
# Difference between R2 score and CVS is: 33.82285520688516

# %%
score=cross_val_score(svr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_svr)-score.mean())*100)
# Out:
# [0.6586121  0.57239341 0.66136582 0.76019103 0.65840481]
# 0.662193437787941
# Difference between R2 score and CVS is: 21.084384753552822

# %%
score=cross_val_score(etr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_etr)-score.mean())*100)
# Out:
# [0.69343014 0.64217179 0.66216718 0.74803938 0.66520121]
# 0.682201938658453
# Difference between R2 score and CVS is: 23.272445533649645

# %% [markdown]
# #In the models where the difference is coming high it means there is over fitting problem. Which means that the model is performing well on the training data but not very well on the unseen data.

# %%
#From the difference we conclude lasso is the best performing model

# %% [markdown]
# ### HyperParameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'alpha':[1.0,.05,.4,2],'fit_intercept':[True,False],
      'copy_X':[True, False],
      'positive':[False,True],
      'random_state':[1,4,10,20]}

# %%
gscv=GridSearchCV(Lasso(),param,cv=5)

# %%
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2], 'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True],
#                          'random_state': [1, 4, 10, 20]})

# %%
gscv.best_params_
# Out:
# {'alpha': 0.05,
#  'copy_X': True,
#  'fit_intercept': True,
#  'positive': False,
#  'random_state': 1}

# %%
Model=Lasso(alpha= 0.05,fit_intercept= True,positive=False,random_state= 1,copy_X=True)

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print("R2 score:",r2_score(y_test,pred))
print("Mean Absolute Error:",mean_absolute_error(y_test,pred))
print("Mean Squared Error:",mean_squared_error(y_test,pred))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 score: 0.7763052745494369
# Mean Absolute Error: 1.0646969072756687
# Mean Squared Error: 1.9513332765277709
# Root Mean Squared Error: 1.3969013123795722

# %%
import pickle
filename='Temperature_forecast.pkl'
pickle.dump(Model,open(filename, 'wb'))  #saved model

# %%
#loading the model

loaded_model=pickle.load(open('Temperature_forecast.pkl','rb'))  #read binary mode
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 77.63052745494369

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","original"])   #using[:] to get all the values of predicted data and actual data
conclusion
# Out:
#                 0          1          2         3          4          5     \
# Predicted  32.072097  31.904944  26.029831  29.23367  30.210357  32.385664
# original   32.600000  31.600000  25.100000  29.70000  29.100000  31.800000
#
#                 6          7         8          9     ...       2063  \
# Predicted  33.790241  30.548112  31.48618  27.860534  ...  29.141428
# original   32.700000  31.200000  33.30000  28.100000  ...  28.100000
#
#                 2064       2065       2066       2067       2068       2069  \
# Predicted  32.416561  28.725827  29.826335  28.822632  28.854619  31.449708
# original   32.700000  26.300000  31.500000  31.100000  32.000000  30.000000
#
#                 2070       2071       2072
# Predicted  27.196615  27.918636  29.301771
# original   26.100000  31.400000  28.400000
#
# [2 rows x 2073 columns]

# %%
#These are the predictions for next day maximum temperature

# %% [markdown]
# ### 2. Predicting Next day's minimum temperature

# %%
#Checking the correlation of target variable only

df.corr()['Next_Tmin'].sort_values(ascending=False)
# Out:
# Next_Tmin           1.000000
# LDAPS_Tmin_lapse    0.868429
# Present_Tmin        0.786074
# Present_Tmax        0.615886
# Next_Tmax           0.584606
# LDAPS_Tmax_lapse    0.546807
# LDAPS_RHmin         0.139054
# LDAPS_CC2           0.083320
# Solar radiation     0.082538
# LDAPS_CC3           0.026777
# LDAPS_PPT2          0.018270
# LDAPS_CC1           0.013205
# LDAPS_WS           -0.015769
# LDAPS_CC4          -0.022019
# LDAPS_PPT1         -0.030299
# LDAPS_LH           -0.051971
# LDAPS_RHmax        -0.103338
# Slope              -0.160899
# DEM                -0.241463
# Name: Next_Tmin, dtype: float64

# %%
#We can see high correlation with LDAPS_Tmin_lapse, Present_Tmin i.e. they are contributing too much in its prediction

# %%
#Visualizing the correlation between the features and the label using bar plot

plt.figure(figsize=(22,7))
df.corr()['Next_Tmin'].sort_values(ascending=False).drop(['Next_Tmin']).plot(kind='bar',color='y')
plt.title("Correlation between features and label using bar plot",fontsize=20)
plt.xlabel("Features")
plt.ylabel("Target variable")
plt.show()

# %% [markdown]
# ### Seperating features and label

# %%
x=df.drop(['Next_Tmin'],axis=1)
y=df["Next_Tmin"]

# %%
x
# Out:
#             Present_Tmax  Present_Tmin  LDAPS_RHmin   LDAPS_RHmax  \
# Date
# 2013-06-30          28.7          21.4    58.255688  3.010904e+08
# 2013-06-30          31.9          21.6    52.263397  2.933820e+08
# 2013-06-30          31.6          23.3    48.690479  2.067649e+08
# 2013-06-30          32.0          23.4    58.239788  3.919422e+08
# 2013-06-30          31.4          21.9    56.174095  2.867371e+08
# ...                  ...           ...          ...           ...
# 2017-08-30          23.1          17.8    24.688997  1.495373e+08
# 2017-08-30          22.5          17.4    30.094858  2.035715e+08
# 2017-08-30          23.3          17.1    26.741310  1.549582e+08
# 2017-08-30          23.3          17.7    24.040634  1.412346e+08
# 2017-08-30          23.2          17.4    22.933014  1.408048e+08
#
#             LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  \
# Date
# 2013-06-30         28.074101         23.006936  6.818887   69.451805
# ...

# %%
print("Feature dimensions:",x.shape)
print("Target dimensions:",y.shape)
# Out:
# Feature dimensions: (6907, 18)
# Target dimensions: (6907,)

# %%
#### Feature scaling using standard scalarisation
#To remove the biasness

from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
#To remove the biasness
# Out:
#       Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# 0        -0.430760     -0.821754     0.193211     0.349662         -0.659354
# 1         0.688750     -0.735346    -0.240045     0.261904         -0.010082
# 2         0.583796     -0.000870    -0.498375    -0.724195          0.077849
# 3         0.723735      0.042335     0.192061     1.383971         -0.063461
# 4         0.513827     -0.605732     0.042707     0.186255         -0.279337
# ...            ...           ...          ...          ...               ...
# 6902     -2.389904     -2.377115    -2.233737    -1.375707         -0.754887
# 6903     -2.599813     -2.549933    -1.842881    -0.760551         -1.159742
# 6904     -2.319935     -2.679546    -2.085350    -1.313992         -1.288685
# 6905     -2.319935     -2.420320    -2.280615    -1.470229         -1.048171
# 6906     -2.354920     -2.549933    -2.360699    -1.475122         -0.708540
#
# ...

# %% [markdown]
# #### Checking Variance Inflation Factor

# %%
#Checking Vif in every scaled column

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#     VIF values          Features
# 0     2.757650      Present_Tmax
# 1     3.017106      Present_Tmin
# 2     5.873903       LDAPS_RHmin
# 3     2.387539       LDAPS_RHmax
# 4     7.545356  LDAPS_Tmax_lapse
# 5     6.571436  LDAPS_Tmin_lapse
# 6     1.197555          LDAPS_WS
# 7     1.517253          LDAPS_LH
# 8     4.699951         LDAPS_CC1
# 9     5.406757         LDAPS_CC2
# 10    4.192018         LDAPS_CC3
# 11    2.556488         LDAPS_CC4
# 12    2.574241        LDAPS_PPT1
# 13    2.047904        LDAPS_PPT2
# 14    2.686571               DEM
# 15    2.651609             Slope
# 16    1.216565   Solar radiation
# 17    3.808773         Next_Tmax

# %%
#We can see high vif in LDAPS_Tmax_lapse and LDAPS_Tmin_lapse

# %%
#Dropping LDAPS_Tmax_lapse

x.drop("LDAPS_Tmax_lapse",axis=1,inplace=True)

# %%
#Checking Vif again

from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif["Features"]=x.columns

vif
# Out:
#     VIF values          Features
# 0     2.726351      Present_Tmax
# 1     3.016173      Present_Tmin
# 2     3.812350       LDAPS_RHmin
# 3     2.352139       LDAPS_RHmax
# 4     3.773177  LDAPS_Tmin_lapse
# 5     1.196992          LDAPS_WS
# 6     1.514840          LDAPS_LH
# 7     4.685276         LDAPS_CC1
# 8     5.337535         LDAPS_CC2
# 9     4.190203         LDAPS_CC3
# 10    2.542839         LDAPS_CC4
# 11    2.566110        LDAPS_PPT1
# 12    2.045429        LDAPS_PPT2
# 13    2.685988               DEM
# 14    2.648209             Slope
# 15    1.154608   Solar radiation
# 16    3.214858         Next_Tmax

# %%
#Vif is reduced i.e. multicolliniarity no longer exists

# %% [markdown]
# #### Modelling

# %%
#Importing libraries

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %% [markdown]
# #### Creating train test split

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum R2 score is:",maxAccu,"on random state",maxRS)
# Out:
# Maximum R2 score is: 0.8446158065442565 on random state 180

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)

# %%
#Importing all the regressor models

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
pred_train=LR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_LR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_LR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2 score: 0.8446158065442565
# R2 score on training data: 82.60616315475345
# Mean Absolute Error: 0.7573522355320552
# Mean Squared Error: 0.9159263996801981
# Root Mean Squared Error: 0.9570404378500409

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR,y=y_test,color='r')
plt.plot(pred_LR,pred_LR,color='b')
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Linear regression")
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_RFR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_RFR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2 score: 0.8979425138021642
# R2 score on training data: 98.46173896149536
# Mean Absolute Error: 0.5912977831481038
# Mean Squared Error: 0.6015872259247493
# Root Mean Squared Error: 0.7756205424850152

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print("R2 score:",r2_score(y_test,pred_knn))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error:",mean_squared_error(y_test,pred_knn))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2 score: 0.8770014774799049
# R2 score on training data: 91.67074330306836
# Mean Absolute Error: 0.646062282669614
# Mean Squared Error: 0.7250260878684649
# Root Mean Squared Error: 0.8514846374823594

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2 score:",r2_score(y_test,pred_GBR))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_GBR))
print("Mean Squared Error:",mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2 score: 0.8898413852745399
# R2 score on training data: 89.98587421432359
# Mean Absolute Error: 0.6321926641251454
# Mean Squared Error: 0.6493400720838842
# Root Mean Squared Error: 0.8058164009772227

# %%
lasso=Lasso()
lasso.fit(x_train,y_train)
pred_lasso=lasso.predict(x_test)
pred_train=lasso.predict(x_train)
print("R2 score:",r2_score(y_test,pred_lasso))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_lasso))
print("Mean Squared Error:",mean_squared_error(y_test,pred_lasso))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# R2 score: 0.5814374535820667
# R2 score on training data: 58.46187542822805
# Mean Absolute Error: 1.2408195001022677
# Mean Squared Error: 2.4672553729909827
# Root Mean Squared Error: 1.570749939675626

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print("R2 score:",r2_score(y_test,pred_rd))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_rd))
print("Mean Squared Error:",mean_squared_error(y_test,pred_rd))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2 score: 0.8446091675556786
# R2 score on training data: 82.60616036325352
# Mean Absolute Error: 0.757366900428068
# Mean Squared Error: 0.9159655338081325
# Root Mean Squared Error: 0.9570608830205801

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
pred_train=dtr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_dtr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_dtr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_dtr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2 score: 0.7615324044025141
# R2 score on training data: 100.0
# Mean Absolute Error: 0.8623594402996142
# Mean Squared Error: 1.405669144450067
# Root Mean Squared Error: 1.1856091870637926

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_svr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_svr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_svr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# R2 score: 0.9038829842919374
# R2 score on training data: 91.39568066798076
# Mean Absolute Error: 0.5776285013678312
# Mean Squared Error: 0.5665705770166726
# Root Mean Squared Error: 0.752708826184915

# %%
from sklearn.ensemble import ExtraTreesRegressor
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
pred_train=etr.predict(x_train)
print("R2 score:",r2_score(y_test,pred_etr))
print("R2 score on training data:",r2_score(y_train,pred_train)*100)
print("Mean Absolute Error:",mean_absolute_error(y_test,pred_etr))
print("Mean Squared Error:",mean_squared_error(y_test,pred_etr))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# R2 score: 0.9075147626405038
# R2 score on training data: 100.0
# Mean Absolute Error: 0.5605776315300589
# Mean Squared Error: 0.5451627259781666
# Root Mean Squared Error: 0.738351356725351

# %%
from sklearn.model_selection import cross_val_score

# %%
#Checking cvs for every model
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.7393741  0.67747019 0.80146426 0.84780442 0.84904095]
# 0.7830307843359564
# Difference between R2 score and CVS is: 6.158502220830009

# %%
score=cross_val_score(RFR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [0.72903934 0.68681678 0.80168949 0.84729294 0.83779226]
# 0.780526161695839
# Difference between R2 score and CVS is: 11.741635210632516

# %%
score=cross_val_score(knn,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_knn)-score.mean())*100)
# Out:
# [0.54939012 0.52782265 0.66649128 0.69769551 0.7660848 ]
# 0.6414968724901892
# Difference between R2 score and CVS is: 23.55046049897157

# %%
score=cross_val_score(GBR,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [0.73215696 0.6859471  0.82570551 0.86190754 0.86186852]
# 0.7935171269816326
# Difference between R2 score and CVS is: 9.632425829290735

# %%
score=cross_val_score(lasso,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_lasso)-score.mean())*100)
# Out:
# [0.54781002 0.40643413 0.56890506 0.46451142 0.62923939]
# 0.5233800020027627
# Difference between R2 score and CVS is: 5.805745157930398

# %%
score=cross_val_score(rd,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_rd)-score.mean())*100)
# Out:
# [0.73936881 0.67751703 0.80145382 0.84781498 0.8490673 ]
# 0.7830443875748767
# Difference between R2 score and CVS is: 6.15647799808019

# %%
score=cross_val_score(dtr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_dtr)-score.mean())*100)
# Out:
# [0.4856128  0.42199751 0.6085412  0.69279099 0.64293078]
# 0.57037465518085
# Difference between R2 score and CVS is: 19.115774922166416

# %%
score=cross_val_score(svr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_svr)-score.mean())*100)
# Out:
# [0.70403232 0.64020447 0.76522703 0.82491069 0.83010522]
# 0.7528959428506184
# Difference between R2 score and CVS is: 15.098704144131892

# %%
score=cross_val_score(etr,x,y)
print(score)
print(score.mean())
print("Difference between R2 score and CVS is:",(r2_score(y_test,pred_etr)-score.mean())*100)
# Out:
# [0.72304765 0.68376064 0.80452659 0.84886628 0.85527146]
# 0.783094522830344
# Difference between R2 score and CVS is: 12.442023981015982

# %% [markdown]
# #In the models where the difference is coming high it means there is over fitting problem. Which means that the model is performing well on the training data but not very well on the unseen data.

# %%
#From the difference we conclude lasso is the best performing model

# %% [markdown]
# #### HyperParameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'alpha':[1.0,.05,.4,2],'fit_intercept':[True,False],
      'copy_X':[True, False],
      'positive':[False,True],
      'random_state':[1,4,10,20]}

# %%
gscv=GridSearchCV(Lasso(),param,cv=5)

# %%
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2], 'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True],
#                          'random_state': [1, 4, 10, 20]})

# %%
gscv.best_params_
# Out:
# {'alpha': 0.05,
#  'copy_X': True,
#  'fit_intercept': True,
#  'positive': False,
#  'random_state': 1}

# %%
Model=Lasso(alpha= 0.05,fit_intercept= True,positive=False,random_state= 1,copy_X=True)

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print("R2 score:",r2_score(y_test,pred))
print("Mean Absolute Error:",mean_absolute_error(y_test,pred))
print("Mean Squared Error:",mean_squared_error(y_test,pred))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 score: 0.8340761732835044
# Mean Absolute Error: 0.7793010861416909
# Mean Squared Error: 0.9780532359546988
# Root Mean Squared Error: 0.9889657405363943

# %%
import pickle
filename='Temperature_forecast_nextday.pkl'
pickle.dump(Model,open(filename, 'wb'))  #saved model

# %%
#loading the model

loaded_model=pickle.load(open('Temperature_forecast_nextday.pkl','rb'))  #read binary mode
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 83.40761732835044

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","original"])   #using[:] to get all the values of predicted data and actual data
conclusion
# Out:
#                 0          1          2         3          4          5     \
# Predicted  24.623036  20.797414  20.715047  21.45144  20.981093  25.999194
# original   25.000000  20.900000  18.000000  21.70000  20.900000  25.100000
#
#                 6         7          8          9     ...       2063  \
# Predicted  20.487825  21.82632  23.890488  24.613866  ...  22.072404
# original   20.100000  20.90000  25.600000  24.300000  ...  21.600000
#
#                 2064       2065       2066       2067       2068      2069  \
# Predicted  24.506566  22.662643  20.356257  21.641158  21.047787  24.78922
# original   26.300000  23.600000  20.500000  21.800000  21.300000  25.10000
#
#                 2070      2071       2072
# Predicted  24.268078  23.21295  20.381568
# original   23.300000  24.00000  20.100000
#
# [2 rows x 2073 columns]

# %%
#These are the predictions for next day minimum temperature
